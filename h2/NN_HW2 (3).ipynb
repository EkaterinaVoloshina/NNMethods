# %%
# !wget https://www.dropbox.com/s/r6u59ljhhjdg6j0/negative.csv
# !wget https://www.dropbox.com/s/fnpq3z4bcnoktiv/positive.csv
# Out:
# --2021-11-26 19:30:36--  https://www.dropbox.com/s/r6u59ljhhjdg6j0/negative.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/r6u59ljhhjdg6j0/negative.csv [following]
# --2021-11-26 19:30:36--  https://www.dropbox.com/s/raw/r6u59ljhhjdg6j0/negative.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-11-26 19:30:36 ERROR 404: Not Found.
#
# --2021-11-26 19:30:36--  https://www.dropbox.com/s/fnpq3z4bcnoktiv/positive.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/fnpq3z4bcnoktiv/positive.csv [following]
# --2021-11-26 19:30:36--  https://www.dropbox.com/s/raw/fnpq3z4bcnoktiv/positive.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-11-26 19:30:37 ERROR 404: Not Found.

# %%
! pip install pymorphy2
# Out:
# Requirement already satisfied: pymorphy2 in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (2.4.417127.4579844)

# %%
! pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.10.0+cu111)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.6)

# %%
import pandas as pd
import numpy as np
from string import punctuation
from collections import Counter
from nltk.tokenize import WordPunctTokenizer
from pymorphy2 import MorphAnalyzer

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import random
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from torch.nn.utils.rnn import pad_sequence
import torch.optim as optim
from torchmetrics.functional import f1

tokenizer = WordPunctTokenizer()
morph = MorphAnalyzer()

# %%
def seed_everything(seed: int): # код из тетрадки по иаду, чтобы зафиксировать все
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything(42)

# %% [markdown]
# # Часть 0.

# %% [markdown]
# Создаем датасет:

# %%
pos_tweets = pd.read_csv('positive.csv', encoding='utf-8', sep=';', header=None,  names=[0,1,2,'text','tone',5,6,7,8,9,10,11])
neg_tweets = pd.read_csv('negative.csv', encoding='utf-8', sep=';', header=None, names=[0,1,2,'text','tone',5,6,7,8,9,10,11] )
neg_tweets['tone'] = 0

# %%
all_tweets_data = pos_tweets.append(neg_tweets)
print(len(all_tweets_data))
# Out:
# 226834

# %%
all_tweets_data.head()
# Out:
#                    0           1                2   ...  9   10  11
# 0  408906692374446080  1386325927  pleease_shut_up  ...  62  61   0
# 1  408906692693221377  1386325927  alinakirpicheva  ...  59  31   2
# 2  408906695083954177  1386325927        EvgeshaRe  ...  26  27   0
# 3  408906695356973056  1386325927    ikonnikova_21  ...  19  17   0
# 4  408906761416867842  1386325943        JumpyAlex  ...  16  23   1
#
# [5 rows x 12 columns]

# %%
def tokenize(text):
    #tokens = tokenizer.tokenize(text.lower())
    tokens = tokenizer.tokenize(text.lower())
    lemmas = [morph.parse(token)[0].normal_form for token in tokens if token not in punctuation]
    return ' '.join(lemmas)

# %%
all_tweets_data['lemmas'] = all_tweets_data['text'].apply(tokenize)

# %%
tweets_data = shuffle(all_tweets_data[['text','tone', 'lemmas']])

# %%
train_sentences, val_sentences = train_test_split(tweets_data, test_size=0.2)

# %% [markdown]
# Теперь создадим vocab2id для токенов, лемм и символов:

# %%
def preprocess(text):
    tokens = text.lower().split()
    tokens = [token.strip(punctuation) for token in tokens]
    return tokens

# %%
word_vocab = Counter()
lemma_vocab = Counter()
symbol_vocab = Counter()

for i, text in tweets_data.iterrows():
    word_vocab.update(preprocess(text[0]))
    lemma_vocab.update(text[2].split())
    symbol_vocab.update(list(text[0]))
print('всего уникальных токенов:', len(word_vocab))
print('всего уникальных лемм:', len(lemma_vocab))
print('всего уникальных символов:', len(symbol_vocab))
# Out:
# всего уникальных токенов: 366250
# всего уникальных лемм: 224582
# всего уникальных символов: 456

# %%
def create2id(vocab, threshold):
    filtered_vocab = set()
    for word in vocab:
        if vocab[word] > threshold:
            filtered_vocab.add(word)
    print(f'уникальных токенов, втретившихся больше {threshold} раз:', len(filtered_vocab))

    word2id = {'PAD':0}
    for word in filtered_vocab:
        word2id[word] = len(word2id)
    id2word = {i:word for word, i in word2id.items()}
    return word2id, id2word

# %%
word2id, id2word = create2id(word_vocab, 2)
lemma2id, id2lemma = create2id(lemma_vocab, 2)
symbol2id, id2symbol = create2id(symbol_vocab, 5)
# Out:
# уникальных токенов, втретившихся больше 2 раз: 64423
# уникальных токенов, втретившихся больше 2 раз: 45069
# уникальных токенов, втретившихся больше 5 раз: 234

# %%
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
DEVICE
# Out:
# device(type='cuda')

# %% [markdown]
# # Часть I.
#
#
# Зададим датасет:

# %%
class TweetsDataset(Dataset):

    def __init__(self, dataset, word2id, DEVICE, text='text'):
        self.dataset = dataset[text].values
        self.word2id = word2id
        self.length = dataset.shape[0]
        self.target = torch.Tensor(dataset['tone'].values)
        self.device = DEVICE


    def __len__(self): #это обязательный метод, он должен уметь считать длину датасета
        return self.length

    def __getitem__(self, index): #еще один обязательный метод. По индексу возвращает элемент выборки
        tokens = self.preprocess(self.dataset[index]) # токенизируем
        ids = torch.LongTensor([self.word2id[token] for token in tokens if token in self.word2id])
        y = self.target[index]
        return ids, y
    
    def preprocess(self, text):
        tokens = text.lower().split()
        tokens = [token.strip(punctuation) for token in tokens]
        tokens = [token for token in tokens if token not in punctuation]
        return tokens

    def collate_fn(self, batch): #этот метод можно реализовывать и отдельно,
    # он понадобится для DataLoader во время итерации по батчам
      ids, y = list(zip(*batch))
      padded_ids = pad_sequence(ids, batch_first=True).to(self.device)
      y = torch.Tensor(y).to(self.device)
      return padded_ids,  y

# %%
train_dataset = TweetsDataset(train_sentences, word2id, DEVICE)
train_sampler = RandomSampler(train_dataset)
train_iterator = DataLoader(train_dataset, collate_fn = train_dataset.collate_fn, sampler=train_sampler, batch_size=64)
val_dataset = TweetsDataset(val_sentences, word2id, DEVICE)
val_sampler = SequentialSampler(val_dataset)
val_iterator = DataLoader(val_dataset, collate_fn = val_dataset.collate_fn, sampler=val_sampler, batch_size=64)

# %% [markdown]
# Теперь зададим архитектуру модели:

# %%
class CNN(nn.Module):
    
    def __init__(self, vocab_size, embedding_dim, pretrained=False):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        if pretrained:
          self.embedding.from_pretrained(torch.tensor(weights), freeze=True)
        self.bigrams = nn.Conv1d(in_channels=embedding_dim, out_channels=100, kernel_size=2, padding='same')
        self.trigrams = nn.Conv1d(in_channels=embedding_dim, out_channels=80, kernel_size=3, padding='same')
        self.conv = nn.Conv1d(in_channels=180, out_channels=100, kernel_size=2)
        self.pooling = nn.MaxPool1d(kernel_size=2, stride=2)
        self.relu = nn.ReLU()
        self.hidden = nn.Linear(in_features=100, out_features=1)
        self.dropout = nn.Dropout(p=0.5)
        self.out = nn.Sigmoid()

    def forward(self, word):
        #batch_size x seq_len
        embedded = self.embedding(word)
        embedded = embedded.transpose(1,2)
        bigrams = self.relu(self.bigrams(embedded))
        trigrams = self.relu(self.trigrams(embedded))
        concat = torch.cat((bigrams, trigrams), 1)
        conv = self.pooling(self.conv(concat)).max(2)[0]
        logits = self.hidden(conv) 
        logits = self.out(logits)      
        return logits

# %%
def train(model, iterator, optimizer, criterion, metric):
    print('Training...')
    epoch_loss = 0 # для подсчета среднего лосса на всех батчах
    epoch_metric = 0
    model.train()  # ставим модель в обучение, явно указываем, что сейчас надо будет хранить градиенты у всех весов

    for i, (texts, ys) in enumerate(iterator): #итерируемся по батчам
        optimizer.zero_grad()  #обнуляем градиенты
        preds = model(texts).squeeze()  #прогоняем данные через модель
        loss = criterion(preds, ys) #считаем значение функции потерь  
        loss.backward() #считаем градиенты  
        optimizer.step() #обновляем веса 
        epoch_loss += loss.item() #сохраняем значение функции потерь
        
        batch_metric = metric(preds.round().long(), ys.long(), ignore_index=0)
        epoch_metric += batch_metric
        #if not (i + 1) % 20:
        #    print(f'Train loss: {loss.item()}, Train f1: {batch_metric}')
            #print(f'Train loss: {epoch_loss/i}, Train f1: {epoch_metric/i}')     
    print(f'F-score: {epoch_metric / len(iterator)}, loss: {epoch_loss / len(iterator)}') 
    return epoch_metric / len(iterator), epoch_loss / len(iterator) # возвращаем среднее значение по всей выборке

# %%
def evaluate(model, iterator, criterion, metric):
    print("\nValidating...")
    epoch_loss = 0
    epoch_metric = 0
    model.eval()
    pred = []
    y = []
    text = []
    with torch.no_grad():
        for i, (texts, ys) in enumerate(iterator):   
            preds = model(texts).squeeze()  # делаем предсказания на тесте
            loss = criterion(preds, ys)   # считаем значения функции ошибки для статистики  
            epoch_loss += loss.item()
            batch_metric = metric(preds.round().long(), ys.long(), ignore_index=0)
            epoch_metric += batch_metric
            pred.extend(preds.round().cpu().tolist())
            y.extend(ys.cpu().tolist())
            text.extend(texts.cpu().tolist())

    print(f'F-score: {epoch_metric / len(iterator)}, loss: {epoch_loss / len(iterator)}')
        
    return epoch_metric / len(iterator), epoch_loss / len(iterator), text, pred, y

# %%
def train_model(model, lr, epochs):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCELoss() 

    model = model.to(DEVICE)
    criterion = criterion.to(DEVICE)

    losses = []
    losses_eval = []
    f1s = []
    f1s_eval = []

    for i in range(epochs):
        print(f'\nstarting Epoch {i}')
        f1_value, epoch_loss = train(model, train_iterator, optimizer, criterion, metric=f1)
        losses.append(epoch_loss)
        f1s.append(f1_value)

        f1_value_on_test, epoch_loss_on_test, texts, preds, ys = evaluate(model, val_iterator, criterion, metric=f1)
        losses_eval.append(epoch_loss_on_test)
        f1s_eval.append(f1_value_on_test)
    return texts, preds, ys

# %%
def compare_preds_ys(texts, preds, ys, id2word):
    for i in range(len(preds)):
        if preds[i] != ys[i]:
            text = ' '.join([id2word[id] for id in texts[i] if id2word[id] != 'PAD'])
            print(f'text: {text}\n label: {ys[i]}, prediction: {preds[i]}')

# %% [markdown]
# Тренируем модель с дефолтными параметрами:

# %%
model = CNN(len(word2id), 8)
texts, preds, ys = train_model(model, 0.001, 3)
# Out:
# starting Epoch 0
# Training...
# F-score: 0.6242083311080933, loss: 0.6217950288369222
#
# Validating...
# F-score: 0.6830612421035767, loss: 0.5853740812945265
#
# starting Epoch 1
# Training...
# F-score: 0.7102341651916504, loss: 0.545849538530382
#
# Validating...
# F-score: 0.7305583953857422, loss: 0.5490723389328283
#
# starting Epoch 2
# Training...
# F-score: 0.7540391087532043, loss: 0.4919508190980583
#
# Validating...
# F-score: 0.7225967645645142, loss: 0.5226638578561532

# %% [markdown]
# F-score равен 0.72, поэтому есть куда улучшать!

# %% [markdown]
# ### 1.2. Используем  эмбеддинги FastText

# %% [markdown]
# Попробуем натренировать FastText на нашем корпусе и загрузить эмбеддинги в модель

# %%
from gensim.models import FastText

# %%
texts = all_tweets_data.text.apply(preprocess).to_list()

# %%
model = FastText(texts, size=100, window=5, min_count=1)

# %%
weights = np.zeros((len(word2id), 100))
count = 0
for word, i in word2id.items():
    if word == 'PAD':
        continue   
    try:
        weights[i] = model.wv[word]    
    except KeyError:
      count += 1
      # oov словам сопоставляем случайный вектор
      weights[i] = np.random.normal(0,0.1,100)

# %%
fasttext_model = CNN(len(word2id), 100, pretrained=True)
texts, preds, ys = train_model(fasttext_model, 0.001, 3)
# Out:
# starting Epoch 0
# Training...
# F-score: 0.6879616975784302, loss: 0.5653806128480034
#
# Validating...
# F-score: 0.74798583984375, loss: 0.5266508212462803
#
# starting Epoch 1
# Training...
# F-score: 0.7758302688598633, loss: 0.45974038883896573
#
# Validating...
# F-score: 0.7539206743240356, loss: 0.4945674329281526
#
# starting Epoch 2
# Training...
# F-score: 0.824968159198761, loss: 0.38293773979368934
#
# Validating...
# F-score: 0.7707210779190063, loss: 0.5062397499851179

# %% [markdown]
# FastText помог улучшить качество! Вероятно, модели не хватило эпох, чтобы обучить эмбеддинги, но она лучше работает с предобученными

# %% [markdown]
# ### Меняем гиперпараметры

# %% [markdown]
# Увеличим размер эмбеддинга:

# %%
model = CNN(len(word2id), 50)
texts, preds, ys = train_model(model, 0.001, 3)
# Out:
# starting Epoch 0
# Training...
# F-score: 0.6716139912605286, loss: 0.5812360862603645
#
# Validating...
# F-score: 0.7122611403465271, loss: 0.5352640655548515
#
# starting Epoch 1
# Training...
# F-score: 0.7596361637115479, loss: 0.48372277561759075
#
# Validating...
# F-score: 0.7534310817718506, loss: 0.5062956153001368
#
# starting Epoch 2
# Training...
# F-score: 0.8064237833023071, loss: 0.41261900751227554
#
# Validating...
# F-score: 0.7586255073547363, loss: 0.5044789119651186

# %% [markdown]
# В целом увеличение эмбеддинга дало лучший результат, так как можно хранить больше информации. Это улучшает качество классификации!

# %% [markdown]
# Теперь уменьшим лернинг рейт:

# %%
model = CNN(len(word2id), 8)
texts, preds, ys = train_model(model, 0.0005, 3)
# Out:
# starting Epoch 0
# Training...
# F-score: 0.6075225472450256, loss: 0.643439017751153
#
# Validating...
# F-score: 0.6385930776596069, loss: 0.6080097086170665
#
# starting Epoch 1
# Training...
# F-score: 0.67527836561203, loss: 0.583494718482111
#
# Validating...
# F-score: 0.690639853477478, loss: 0.5764812672003704
#
# starting Epoch 2
# Training...
# F-score: 0.7140663862228394, loss: 0.5424197400553606
#
# Validating...
# F-score: 0.6893985867500305, loss: 0.557993971284253

# %% [markdown]
# Уменьшение лернинг рейта испортила качество модели, так как, вероятно, модель не дошла до локального минимума, двигаясь со слишком маленьким шагом

# %% [markdown]
# ### 3. Изменим предобработку

# %% [markdown]
# Теперь попробуем прогнать нашу модель на лемматизированных текстах:

# %%
train_dataset = TweetsDataset(train_sentences, lemma2id, DEVICE, text='lemmas')
train_sampler = RandomSampler(train_dataset)
train_iterator = DataLoader(train_dataset, collate_fn = train_dataset.collate_fn, sampler=train_sampler, batch_size=64)
val_dataset = TweetsDataset(val_sentences, lemma2id, DEVICE, text='lemmas')
val_sampler = SequentialSampler(val_dataset)
val_iterator = DataLoader(val_dataset, collate_fn = val_dataset.collate_fn, sampler=val_sampler, batch_size=64)

# %%
model = CNN(len(lemma2id), 10)
texts, preds, ys = train_model(model, 0.001, 3)
# Out:
# starting Epoch 0
# Training...
# F-score: 0.6590145826339722, loss: 0.5793229791063852
#
# Validating...
# F-score: 0.735237717628479, loss: 0.5479381499741074
#
# starting Epoch 1
# Training...
# F-score: 0.7435637712478638, loss: 0.4981963251348275
#
# Validating...
# F-score: 0.7594826817512512, loss: 0.506949861017706
#
# starting Epoch 2
# Training...
# F-score: 0.7781262993812561, loss: 0.45264485238805646
#
# Validating...
# F-score: 0.745878279209137, loss: 0.48175536665660873

# %%
compare_preds_ys(texts, preds, ys, id2lemma)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# text: 33 19 42 а у ты с
#  label: 0.0, prediction: 1.0
# text: существовать « синдром взрываться голова » о который вы наверняка не слышать
#  label: 1.0, prediction: 0.0
# text: ага особенно тот что рядом с я остаться только рожок пририсовать
#  label: 1.0, prediction: 0.0
# text: оу я вспомнить что весна кой кто так и не дать я урок катание на борд хотеть вспомнить и хочууа
#  label: 1.0, prediction: 0.0
# text: rt маленький знать хороший спать
#  label: 0.0, prediction: 1.0
# text: привет это гарри стайлс который в детство быть ублюдок http t co
#  label: 0.0, prediction: 1.0
# text: слушать визг и ор в трубка от так всё потому что еда на нг домой 31 в
#  label: 1.0, prediction: 0.0
# text: с но всё таки здесь есть личный сообщение а я обещать никто не рассказывать
#  label: 1.0, prediction: 0.0
# text: и как обычно когда нужно подтянуть оценка я начинать заболевать
#  label: 0.0, prediction: 1.0
# text: я неудачница я окружать друг предатель с который я всё равно продолжать общаться
#  label: 0.0, prediction: 1.0
# text: собираться на тренировка лёня но нужно идти http t co
#  label: 0.0, prediction: 1.0
# text: свой школьный подруга давно не видеться а сказать друг друг не что
#  label: 0.0, prediction: 1.0
# text: отличный вечер но к суша не притронуться целый неделя теперь http t co
#  label: 1.0, prediction: 0.0
# text: спереть терминатор да прийти спаситель блин уметь же делать красиво
#  label: 0.0, prediction: 1.0
# text: от мой родный наконец то прийти открытка я так ты любить и скучать http t co
#  label: 0.0, prediction: 1.0
# text: rt lavrov_evgeny лаборатория касперский официально заявить что эдвард сноуден не работать в они компания
#  label: 1.0, prediction: 0.0
# text: rt с ты как в евросоюз нет граница
#  label: 1.0, prediction: 0.0
# text: я казаться что в москва они уже гораздо большой
#  label: 1.0, prediction: 0.0
# text: на я бы тем более сходить я бы на место группа детство
#  label: 0.0, prediction: 1.0
# text: это для фича он стать бесплатный а опция внутренний покупка не убрать но сделать тоже бесплатный
#  label: 0.0, prediction: 1.0
# text: пойти она подумать иван петрович директор школа № 7 и завалиться снова спать http t co
#  label: 1.0, prediction: 0.0
# text: завтра снова урок сократить з но быть кр по математика я снова написать на 4 я знать
#  label: 1.0, prediction: 0.0
# text: bloodymoonnick kronos_son ну хватить элла поть угарать надо я быть ахахахахаа
#  label: 1.0, prediction: 0.0
# text: считаться что в это год в июнь хороший весь ехать в черногория так говорить в lonely planet
#  label: 1.0, prediction: 0.0
# text: добрый утро супер мег бизнес центр на профессор попов далее 37 остаться без связь
#  label: 0.0, prediction: 1.0
# text: это быть забавно прощать отбросик http t co
#  label: 0.0, prediction: 1.0
# text: тот я завтра всё делать быть для тот что бы поздно не быть
#  label: 1.0, prediction: 0.0
# text: крутой весь в коридор в болгария ещё 4 год назад скрывать что зейня ватруха у mix — http t co
#  label: 0.0, prediction: 1.0
# text: снова банк кто я ещё нужный то
#  label: 1.0, prediction: 0.0
# text: и вообще объявлять день скорбь в память о шарф
#  label: 0.0, prediction: 1.0
# text: дмитрий дмитриевич ну что очередной долгожданный 7 декабрь наступить
#  label: 1.0, prediction: 0.0
# text: rianru жалкий картина за конфетка купить мент сам не на митинг за конфетка
#  label: 1.0, prediction: 0.0
# text: lponomarenko_o спасибо 3 а ты давать стараться чтоб без тройка я следить за ты
#  label: 0.0, prediction: 1.0
# text: попробовать кофе в блендер не пытаться повторить это бесполезно
#  label: 0.0, prediction: 1.0
# text: зато теперь я точно уверить что ночь пройти не зря а рано утром вставать и работать много много работать
#  label: 1.0, prediction: 0.0
# text: я думать что мы большой никогда не увидесться но сегодня я мочь немного побыть с ты сон я любить ты http t co
#  label: 1.0, prediction: 0.0
# text: rt подарить я кто нибыть солнце плиз мочь это я согреть
#  label: 0.0, prediction: 1.0
# text: я казаться в хороший играть есть воля характер а хотеть биться а забить не мочь второй тайм пока не проигрывать
#  label: 1.0, prediction: 0.0
# text: в уругвай есть тюрьма под название freedom http t co
#  label: 1.0, prediction: 0.0
# text: rt пропустить 14 15 мочь это и к хороший
#  label: 1.0, prediction: 0.0
# text: что утро добрый не бывать бывать господин бывать
#  label: 1.0, prediction: 0.0
# text: tarjayara понедельник среда – с 14 00 до 17 30 час вторник четверг пятница – с 9 00 до 12 30 час ленин 4 бывший учебный центр
#  label: 1.0, prediction: 0.0
# text: пиво много жрачок интернет телек два диван у я рай для одиночка
#  label: 0.0, prediction: 1.0
# text: в первый пожалуйста давать без квадратик они я смущать а в второй вообще не смешно
#  label: 1.0, prediction: 0.0
# text: надо спать спать спать но как то лень что ли вот я ленивый
#  label: 1.0, prediction: 0.0
# text: rt после каждый происшествие в волгоград возникать волнующий вопрос как там серёжа
#  label: 0.0, prediction: 1.0
# text: сессия скоро я один не паниковать всё или почти билет есть а я даже в рука они не брать
#  label: 1.0, prediction: 0.0
# text: пересадить на 1 парта теперь смотреть какой ангелочек
#  label: 1.0, prediction: 0.0
# text: о великий контакт покоритель мозг отпустить покушать на полчасика
#  label: 1.0, prediction: 0.0
# text: сидеть и думать что да слово такой странный разорить и существовать ли ооо вобщий а мы вобщий существовать
#  label: 0.0, prediction: 1.0
# text: rt anonim_ykt14 лайк если не успеть загадать желание 11 12 13 14 15
#  label: 0.0, prediction: 1.0
# text: ну пиздец прошляпить желание в 14 15 последний
#  label: 1.0, prediction: 0.0
# text: bitcheswildcard да они на он развитие ещё в третий сезон забить
#  label: 0.0, prediction: 1.0
# text: я не понимать этот позиция но пусть мой звонок в время сон быть самый ужасный что мочь произойти сегодня
#  label: 1.0, prediction: 0.0
# text: ахахах зато сан дия ку
#  label: 0.0, prediction: 1.0
# text: rt предел одиночество это когда подарок на новый год покупать сам себя
#  label: 0.0, prediction: 1.0
# text: в программа голос как всегда побеждать слабый участник что за несправедливость
#  label: 0.0, prediction: 1.0
# text: всім привіт нарешті у твіттереть
#  label: 1.0, prediction: 0.0
# text: я фигей с новый расписание http t co
#  label: 0.0, prediction: 1.0
# text: өнөө цаг үе минь ийм л болж шд http t co
#  label: 0.0, prediction: 1.0
# text: прийти на ночёвка к соня почти уснуть и тут коварный скрип дверь … вожатый жрать ночью и запалить я
#  label: 0.0, prediction: 1.0
# text: после клон быть смотреть земля любовь земля надежда очередной бразильский хует
#  label: 1.0, prediction: 0.0
# text: rt oopso_o_o i_ammorgenstern привет о
#  label: 0.0, prediction: 1.0
# text: гадаадада ирсэн гэсэн нэртэя бгаад ажилд
#  label: 0.0, prediction: 1.0
# text: rt сегодня в 14 15 нужно быть загадать желание а мы как всегда просрали
#  label: 0.0, prediction: 1.0
# text: rt мой гарри поттер
#  label: 1.0, prediction: 0.0
# text: нееет она там есть там два красный
#  label: 0.0, prediction: 1.0
# text: alex пробить 15 600 000 урон теперь ты в курс как не крутить http t co
#  label: 1.0, prediction: 0.0
# text: прийти сегодня в офис в майка ненавидеть понедельник ловить взгляд сотрудник
#  label: 1.0, prediction: 0.0
# text: какой то первоклашка посмотреть на настя и она стать кошмарно плохо кстати это быть бы жесть сон про мистика и убийство
#  label: 0.0, prediction: 1.0
# text: rt prisonero_o с день рождение чувак весь сам упороть и добрый ты 3
#  label: 0.0, prediction: 1.0
# text: therealguf уже ничего 3 день не писать поход опять r i
#  label: 1.0, prediction: 0.0
# text: rt yamoneynews ilyabirman ну простить мы уже поправить
#  label: 0.0, prediction: 1.0
# text: rt выкидывать учебник всё сразу себя еле рюкзак
#  label: 1.0, prediction: 0.0
# text: как символ поддержка из снг
#  label: 1.0, prediction: 0.0
# text: ты че афигесть а как же физика d
#  label: 0.0, prediction: 1.0
# text: перед новый год с гриша опять поехать в только уже с ночёвка ночью пойти в клуб
#  label: 1.0, prediction: 0.0
# text: интересно зачем чекиниться дом видеть только один причина чтобы мама с папа не волноваться
#  label: 1.0, prediction: 0.0
# text: rt с утро прищемить палец теперь чёрный титька утро не задаться
#  label: 1.0, prediction: 0.0
# text: в понедельник компьютерный диагностик с и в екб ехать аааааааааааааааааааааа ужс сс
#  label: 0.0, prediction: 1.0
# text: dmaijac ну вот столько прожить про это не знать
#  label: 1.0, prediction: 0.0
# text: а почему длина теперь разный если резать то под один
#  label: 1.0, prediction: 0.0
# text: блоха vorobievaya картинка от fascinatingpics очень хорошо описывать состояние http t co
#  label: 1.0, prediction: 0.0
# text: choco_funky не у я ток глаз сделать а у она даж мозг накатить непонятный хуйня
#  label: 1.0, prediction: 0.0
# text: мерить 2 размер и купить в итог тот что большой в это весь я
#  label: 0.0, prediction: 1.0
# text: rt http t co не лёгкий быть сразу помириться
#  label: 0.0, prediction: 1.0
# text: куртка махнуться ждать фотка от дашка
#  label: 1.0, prediction: 0.0
# text: специфика работа в районный газета на пример газета « маршрутка » г
#  label: 0.0, prediction: 1.0
# text: ахи мы проиграть всё равно
#  label: 1.0, prediction: 0.0
# text: это не к я вася сказать я просто далеко жить а так бы взять
#  label: 0.0, prediction: 1.0
# text: сегодня на мой глаз разбить сердце девушка правда оно быть в вид пятый айфон но всё равно карина жалко
#  label: 1.0, prediction: 0.0
# text: sopli32 я не про аудитория а про конкретный человек
#  label: 1.0, prediction: 0.0
# text: e_sivanova срочно всё 59 к метро спасти двор и улица от транспорт задыхаться от тысяча машина
#  label: 0.0, prediction: 1.0
# text: конечно я уверить они очень вкусный прям сам захотеться
#  label: 0.0, prediction: 1.0
# text: не о это ли договариваться с шейх
#  label: 0.0, prediction: 1.0
# text: добро недобрый утро а где то происходить заключительный репетиция презентация
#  label: 1.0, prediction: 0.0
# text: w_dancer м да я рядом с такой стыдиться надо
#  label: 0.0, prediction: 1.0
# text: сегодня для тот чтобы выделяться достаточно просто не курить и читать книга
#  label: 0.0, prediction: 1.0
# text: kapsya72 kozlovskyd вот с радость если б москва
#  label: 0.0, prediction: 1.0
# text: у я иногда такой чувство что мой друг регулярно курить шмаля и главное то что они не делиться с я
#  label: 0.0, prediction: 1.0
# text: http t co жесть вот она « культура » общение на
#  label: 0.0, prediction: 1.0
# text: начальство ваш рехнуться сорри
#  label: 0.0, prediction: 1.0
# text: в поликлиника так вонять мазь как будто всё врач намазаться сразу вспоминаться
#  label: 1.0, prediction: 0.0
# text: rt shzphaction и всё же не называть себя стадо не про ты это
#  label: 0.0, prediction: 1.0
# text: у он там просто жена работать правда директор ижевск биатлон
#  label: 1.0, prediction: 0.0
# text: frau_ns так и я тв не пользоваться вообще причём давно я предпочитать читать и зырить фильм в айфон но твиттер никто не отменять
#  label: 1.0, prediction: 0.0
# text: пупсик спать уйти быть тоже тогда спатенёк ложиться
#  label: 0.0, prediction: 1.0
# text: в 2014 я встреча свой половинка ахахи скорее бы
#  label: 0.0, prediction: 1.0
# text: это быть самый хороший беседа даже без девятка можно обойтись
#  label: 1.0, prediction: 0.0
# text: если медсестра запалить отобрать телефон она психованный какой то прощать любимый
#  label: 0.0, prediction: 1.0
# text: казаться я завалить тви ахи пойти спать лечиться там блин
#  label: 1.0, prediction: 0.0
# text: брат вернуться из армия 3 http t co
#  label: 1.0, prediction: 0.0
# text: в четверг он быть некогда
#  label: 1.0, prediction: 0.0
# text: про себя принцесса показать она храбрый сердце
#  label: 1.0, prediction: 0.0
# text: innaastakhova20 ихний дело делать а растить должный кто то другой
#  label: 0.0, prediction: 1.0
# text: каплан петь космос мы ждать а я в туалет короче
#  label: 0.0, prediction: 1.0
# text: karimova00 а повернуться и показать лень значит не давать
#  label: 1.0, prediction: 0.0
# text: любимый я скучать по наш лёт http t co
#  label: 1.0, prediction: 0.0
# text: начать разбираться в код архиватор по алгоритм
#  label: 1.0, prediction: 0.0
# text: давать персик переходить в барс быть скамейка охранять
#  label: 1.0, prediction: 0.0
# text: холодно наверное украинец на мороз то стоять блокада строить майдан
#  label: 1.0, prediction: 0.0
# text: сейчас быть снова пересматривать волчонок в пятый раз
#  label: 1.0, prediction: 0.0
# text: я за гуляш за батон душа
#  label: 1.0, prediction: 0.0
# text: rt marinkafetisova круть а у мы и не проходить даже а где ты жить я только что рассказать что у ты конфета раздавать мы …
#  label: 0.0, prediction: 1.0
# text: rt indraa1001 даанч л одоо бусы
#  label: 0.0, prediction: 1.0
# text: rt gordeev_tima не грусть ты хороший возможно она даже и не понимать что ты обижаться
#  label: 0.0, prediction: 1.0
# text: happy new year правда настроение нифига
#  label: 0.0, prediction: 1.0
# text: ахи не царский это дело уборка
#  label: 1.0, prediction: 0.0
# text: если кто ещё не видеть мой бред miss me — фанфик по фэндом « шерлок » http t co
#  label: 0.0, prediction: 1.0
# text: “ rt_russian украинский оппозиция собирать гражданин страна на марш миллион у мы быть не собрать запад ты повторяться другой идея нет
#  label: 1.0, prediction: 0.0
# text: в город шавка значит
#  label: 1.0, prediction: 0.0
# text: lizzorro потому что я любить такой тея http t co
#  label: 0.0, prediction: 1.0
# text: команда квн самара добраться до первый быть выступать в там сплошь ребята который с мы в играть а мы курсач шпарить
#  label: 0.0, prediction: 1.0
# text: norimyxxxo странный доска
#  label: 0.0, prediction: 1.0
# text: и когда он увидеть я не в джинсы и кед он охуесть
#  label: 1.0, prediction: 0.0
# text: это хорошо но знакомиться с человек по сеть я давно разучиться признаться расхотеться а между тем есть клёвый ох
#  label: 0.0, prediction: 1.0
# text: куда бы кинуть трудовой сандро там в академия художество препод в архитектурный сфера не нужный
#  label: 1.0, prediction: 0.0
# text: panicsara мы писать контрольный а я писать один вариант с говнюк и я она не сдать рабочий тетрадь кароч завтра я на химия не идти
#  label: 1.0, prediction: 0.0
# text: не болеть всё около быть только сон ебануть пиздеец
#  label: 1.0, prediction: 0.0
# text: rt redhot4ili даже латынина обогнать rt barak_obmana обама удостоиться премия за самый крупный ложь год http t co via …
#  label: 0.0, prediction: 1.0
# text: rt два неделя напряга и свобода
#  label: 1.0, prediction: 0.0
# text: ладный дубль 2 линт покидать я фото отец в шапка сант клаус а то хотеть новогодний юп а поставить нечего с
#  label: 1.0, prediction: 0.0
# text: palehovapolina я просто за завтрак нечего большой смотреть
#  label: 0.0, prediction: 1.0
# text: я кстати спрашивать в магазин они вообще хз что это
#  label: 0.0, prediction: 1.0
# text: lira_belaqua hifdin ты токо пойти писать я с утро писать потом в твиттер и всё на это
#  label: 1.0, prediction: 0.0
# text: rykov видео не хотеть записывать быть странно выглядеть
#  label: 1.0, prediction: 0.0
# text: свекровь говорить что не надо быть я на работа устраиваться зарабатывать должный муж и тут я с она солидарный
#  label: 1.0, prediction: 0.0
# text: я на орейра быть писать админ девка её группа в вк нажраться водка перед концерт и вообще полный неадекват так что
#  label: 0.0, prediction: 1.0
# text: да 3 я вообще не думать что это всё правда а счёт телефон а она так быстро я он купить я давно это хотеть
#  label: 1.0, prediction: 0.0
# text: забить всё нормально начать с тот что я действительно не мочь на выходной вообще на этот не то что в москва приехать даже
#  label: 1.0, prediction: 0.0
# text: спасибо ☺️☺️☺️ ох уж это селфи болезнь фронтальный камера
#  label: 0.0, prediction: 1.0
# text: в смысл никто не трогать и я спокойно отсидеть всё пара
#  label: 1.0, prediction: 0.0
# text: jungyoongri ненен бро знать я сегодня послать к весь х чёрт один к это невозможно хороший быть один поверь я
#  label: 0.0, prediction: 1.0
# text: дааааа там много весь быть но главное что как он с мы пить так он не пить не с кто
#  label: 1.0, prediction: 0.0
# text: заебись встречать нг с прыщ http t co
#  label: 0.0, prediction: 1.0
# text: последний урок светлана николаевич расстроить но рада тем что весь класс досидеть до конец … http t co
#  label: 0.0, prediction: 1.0
# text: оу тот нет не так я нрав малый вверху в окно
#  label: 1.0, prediction: 0.0
# text: и это после такой поистине царский подарок от норвегия и чехия биатлон провал россия
#  label: 0.0, prediction: 1.0
# text: я себя девушка то вообще не ощущать с вы я себя не ощущать я боль да из за любовь
#  label: 1.0, prediction: 0.0
# text: я разгадать этот секрет там какой то режим надо изменить
#  label: 1.0, prediction: 0.0
# text: булочка любимый я не быть заставлять ты остаться но я быть ждать твой возвращение
#  label: 1.0, prediction: 0.0
# text: салют каждый день как былой веселие а вообще я казаться это « принцесса » заказывать они на свадьба « хотеть чтобы быть бабах »
#  label: 0.0, prediction: 1.0
# text: зачем ты то они читать или я что то не знать
#  label: 1.0, prediction: 0.0
# text: я представляться гиг где всё стоять и качать голова в такт
#  label: 1.0, prediction: 0.0
# text: няшность свой из ты же няша делать сегодня
#  label: 1.0, prediction: 0.0
# text: напиться в и спать пойти
#  label: 1.0, prediction: 0.0
# text: только я мочь лежать с 3 зарядка слушать музыка и читать твиттер
#  label: 1.0, prediction: 0.0
# text: rt на урок я нормальный голос лен блядь тихий голос ушко лена повернуться …
#  label: 1.0, prediction: 0.0
# text: третий час ночь а я только закончить читать и идти спать ну что ж завтра быть весёлый утро 3
#  label: 1.0, prediction: 0.0
# text: у папа тяжёлый работа а он после 0 00 ехать на работа папа быть аккуратный
#  label: 1.0, prediction: 0.0
# text: я уже почти 2 неделя на больничный каникулы прям аахха
#  label: 1.0, prediction: 0.0
# text: ито ми
#  label: 1.0, prediction: 0.0
# text: у я нет такой фотка я тогда не реветь
#  label: 1.0, prediction: 0.0
# text: это неудача miss_noga1d http t co
#  label: 0.0, prediction: 1.0
# text: rt lubopitner tvrain долой старый обезьяна чтобы молодой ещё большой не набежать
#  label: 1.0, prediction: 0.0
# text: не искать идеальный человек я сегодня дом сидеть
#  label: 1.0, prediction: 0.0
# text: nanaonni15 бля я уже опять нюх быть спасибо что напомнить хд
#  label: 1.0, prediction: 0.0
# text: sfgo76 да голодать надо по час аки полонский bulgari1971
#  label: 1.0, prediction: 0.0
# text: выкинуть убунт воткнуть дебиана шестой на нетбук проц греться сильно температура — 70 градус если особо
#  label: 0.0, prediction: 1.0
# text: проблема в тот что сам он никогда не уйти elenium72 а он электорат это провинция рф быть голосовать за пенсия до год
#  label: 0.0, prediction: 1.0
# text: q вернуться к он a http t co
#  label: 0.0, prediction: 1.0
# text: голодать британец предложить еда с скидка всё печаль http t co
#  label: 1.0, prediction: 0.0
# text: rt micicarulam никогда ранний не слыхать интерпретация слово как
#  label: 1.0, prediction: 0.0
# text: не иначе быть в это время в уфа
#  label: 1.0, prediction: 0.0
# text: перевести на черёмушки на теперь надо встовать ещё ранний чтобы добриться до работа
#  label: 0.0, prediction: 1.0
# text: если в кран нет вода значит кран подъёмный
#  label: 1.0, prediction: 0.0
# text: да я уже сказать хорошо что матан не пропустить
#  label: 1.0, prediction: 0.0
# text: добрый утро юля я сегодня оставить в одиночество
#  label: 0.0, prediction: 1.0
# text: rt lincoln_hey he_hooorm но мой зая быть я читать мой крошка мой пупсик мой пони
#  label: 1.0, prediction: 0.0
# text: сегодня ещё провести время с никитка и вадим давно они не видеть соскучиться
#  label: 0.0, prediction: 1.0
# text: быть бы раздел игра такой же как раздел фильм цена бы она не быть
#  label: 1.0, prediction: 0.0
# text: изз 500 проблема не бывать
#  label: 1.0, prediction: 0.0
# text: это быть ясно в процесс к вечер как раз
#  label: 0.0, prediction: 1.0
# text: именно rt tatcenter_ru фото с официальный сайт команда рубин http t co бердыев http t co
#  label: 0.0, prediction: 1.0
# text: у кто то наконец то наступить зима а я далёкий сидеть с свой осень и я норма
#  label: 0.0, prediction: 1.0
# text: смотреть уже хотеть что то новый посмотреть
#  label: 1.0, prediction: 0.0
# text: ну у ты быть такой шикарный длинный волос
#  label: 0.0, prediction: 1.0
# text: милый то какой от я это карапузик расцеловать
#  label: 1.0, prediction: 0.0
# text: ва премьера ва http t co http t co
#  label: 0.0, prediction: 1.0
# text: пойти спать чувствовать себя не очень весь спокойный ночь
#  label: 0.0, prediction: 1.0
# text: первый сезон классный а второй не страшно и не интересно
#  label: 1.0, prediction: 0.0
# text: ты не видеть этот фотка о как так
#  label: 1.0, prediction: 0.0
# text: ахуенный отчетник пролететь мгновенно а я так переживать ведь всё обойтись
#  label: 1.0, prediction: 0.0
# text: бля второй день в запой и сегодня продолжить
#  label: 1.0, prediction: 0.0
# text: а я артефакт ретвитнуть мой уведомление разрываться
#  label: 1.0, prediction: 0.0
# text: http t co в наш время настроение зависеть от интернет
#  label: 1.0, prediction: 0.0
# text: rt в школа wifi да ещё и в география вай вай вай
#  label: 1.0, prediction: 0.0
# text: письмо бумажный хотеть открытка хотеть эпистолярный жанр помирать
#  label: 0.0, prediction: 1.0
# text: у я кончиться мандаринка спасибо мой большой и дружный семья з
#  label: 0.0, prediction: 1.0
# text: rt lebedeff_alex михаилович плохо переносить алкоголь бывало купить в магазин бутылка а до дом не донести
#  label: 1.0, prediction: 0.0
# text: я себя успокаивать у мы просто разный понятие о дружба и ценность у мы просто разный понятие о дружба и ценность просто разный понятие
#  label: 0.0, prediction: 1.0
# text: никакой с ты
#  label: 1.0, prediction: 0.0
# text: rt какой у квартира номер красивый хих вообщий вот он ещё ты розочка купить http t co
#  label: 0.0, prediction: 1.0
# text: rt anastasya_star maryashao_o sycheva_n хорошо ждать бэйба
#  label: 0.0, prediction: 1.0
# text: rt badgoodsofi я вот что тут подумать мочь кто хотеть твит с картинка кто надо rt rt rt rt
#  label: 0.0, prediction: 1.0
# text: nialler_best да ладный не увезти мама не быть такой делать
#  label: 1.0, prediction: 0.0
# text: оу привет неужели ты я потерять
#  label: 1.0, prediction: 0.0
# text: да первый классный с 3 ещё не смотреть
#  label: 0.0, prediction: 1.0
# text: мама ☺ а ведь наступить тот день когда ты быть надевать я свадебный платье
#  label: 1.0, prediction: 0.0
# text: добрый хотя оно не добрый надо в школа
#  label: 0.0, prediction: 1.0
# text: хахах наивный думать что всё сделать ага конечно в итог не сделать и не выспаться да ну и фига с она выкрутиться
#  label: 0.0, prediction: 1.0
# text: rt volkonavt haritonowagalya elleniy9 silivan_spb почему то зверюшка вызывать жалость рот скотч на нога повязка
#  label: 0.0, prediction: 1.0
# text: rt myhousemars ludiprijatelj да нет я всмысл просто ночь праздник ничего такой мой мысль чистый и невинный ахаз да 3
#  label: 1.0, prediction: 0.0
# text: не ты что с такой деньга вряд ли
#  label: 1.0, prediction: 0.0
# text: olya_latiko только запомнить брать второй версия первый перевод не брать а то мой самооценка упасть ниже
#  label: 1.0, prediction: 0.0
# text: чувак сегодня быть вообще по кайф это наш последний год поэтому я запомнить этот день навсегда http t co
#  label: 0.0, prediction: 1.0
# text: тат и он жена анжелика p s фото больший размер найти не удаться http t co
#  label: 0.0, prediction: 1.0
# text: “ мы тут недавно обсуждать что надо бы в и я прийти к вывод что я не нежный который совратить я ” туохнуть
#  label: 0.0, prediction: 1.0
# text: rt igorzhe rykov у я такой что укр власть наоборот хотеть чтобы быть майдан они на работа ходить не надо
#  label: 1.0, prediction: 0.0
# text: бедный ты кстати к мой дом подойти или к
#  label: 0.0, prediction: 1.0
# text: ты частый смотреть вниз или вверх — вверх ибо мой рост http t co
#  label: 0.0, prediction: 1.0
# text: да и поэтому надо
#  label: 0.0, prediction: 1.0
# text: ничего так а вот подкачать
#  label: 1.0, prediction: 0.0
# text: я тоже в фея даже специально покупать киндёр для девочка но винкс у я есть блум и стелла но они потеряться
#  label: 0.0, prediction: 1.0
# text: мой подруга придумать про я песня
#  label: 0.0, prediction: 1.0
# text: rt http t co энийга л
#  label: 1.0, prediction: 0.0
# text: палец совсем отвыкнуть от гитара а тот даже практически не расстроить
#  label: 1.0, prediction: 0.0
# text: aavst bbcrussian очень правосудие в английский королевство только он реабилитировать с этот статья
#  label: 0.0, prediction: 1.0
# text: это быть очень мило 3 но я как всегда
#  label: 0.0, prediction: 1.0
# text: валяться в ванна с пена и слушать любимый наверно это мой рай today now … http t co
#  label: 0.0, prediction: 1.0
# text: rt человек клясться я в любовь а потом уходить бухать
#  label: 1.0, prediction: 0.0
# text: я приехать из тайга и трое сутки без женщина
#  label: 0.0, prediction: 1.0
# text: там про квн быть бляяять я бы в плюс быть
#  label: 1.0, prediction: 0.0
# text: karadzhaa почитать и бунин ещё
#  label: 1.0, prediction: 0.0
# text: даа это типо так же как бля заяш я не пить аххах
#  label: 1.0, prediction: 0.0
# text: о бог компьютер не грузить снова вообщий я спать
#  label: 1.0, prediction: 0.0
# text: а я из банька еда внизу то питьевой есть
#  label: 1.0, prediction: 0.0
# text: rt глядик а у я в френд сознательный и ленивый народ только парочка прислать волшебный ссылка
#  label: 1.0, prediction: 0.0
# text: удалить и поставить снова я себя гордиться
#  label: 1.0, prediction: 0.0
# text: ахи ага я тоже как то читать но потом незаметно уснуть хд проснуться телефон под я как я он не раздавить ахи
#  label: 1.0, prediction: 0.0
# text: pingvinello не такой яркий натуральный увы но в душа мой цвет
#  label: 1.0, prediction: 0.0
# text: на улица снег сугроб по колено 15
#  label: 0.0, prediction: 1.0
# text: аааа всё наоборот никогда не думать о это
#  label: 1.0, prediction: 0.0
# text: но есть же один который никогда не меняться
#  label: 1.0, prediction: 0.0
# text: печаль наверняка что то химичить правительство чтоб в сочи снег быть к олимпиада
#  label: 0.0, prediction: 1.0
# text: whatsapp viber правда заходить только вечером
#  label: 0.0, prediction: 1.0
# text: за пол час я выучить двадцать один строка я остаться выучить 30 строка и всё я
#  label: 1.0, prediction: 0.0
# text: у ты оч аккуратный это точно
#  label: 1.0, prediction: 0.0
# text: verabrezhneva ахах http t co у я на телефон такой песня правда на он никто не звонить
#  label: 0.0, prediction: 1.0
# text: как то всё быстро закрутиться я даже и не понять как оказаться в статус в гражданский брак
#  label: 1.0, prediction: 0.0
# text: а ещё я есть в 12 забыть поесть перед выход
#  label: 0.0, prediction: 1.0
# text: 23 удаться с утро gmail
#  label: 1.0, prediction: 0.0
# text: самый вариант жеребьёвка да да там любой соперник быть бы ужас но арсенал умудриться на сам жёсткий попасть
#  label: 0.0, prediction: 1.0
# text: с я вы всё нe
#  label: 1.0, prediction: 0.0
# text: ну не то чтобы я они совсем не любить они милый но у я нет особый желание быть владелец
#  label: 1.0, prediction: 0.0
# text: ну так весь ипотека такой я искренне жаль человек который вписываться в этот хуйня
#  label: 1.0, prediction: 0.0
# text: ну вот последний день битвахор http t co
#  label: 1.0, prediction: 0.0
# text: ахахи блин сделать с я лох сейчас
#  label: 1.0, prediction: 0.0
# text: rt за with http t co
#  label: 1.0, prediction: 0.0
# text: чай зелёный ahmad ахмад 20саше по 2гр
#  label: 0.0, prediction: 1.0
# text: rt nati_azur danjawaliyllina такой только маленький http t co
#  label: 1.0, prediction: 0.0
# text: krilovavaleria хорошо и крепко но мало какой то не знать тяжёлый сон быть ты как
#  label: 1.0, prediction: 0.0
# text: rt галстук а где
#  label: 1.0, prediction: 0.0
# text: мой первый в 8 30 начинаться я в поликлиника
#  label: 0.0, prediction: 1.0
# text: kashasavogstyle ну как нить заинстаграмить губа алый
#  label: 1.0, prediction: 0.0
# text: to_nyasha надеяться что это нормасный план а не шуточка
#  label: 1.0, prediction: 0.0
# text: сегодня поймать себя на мысль что очень хотеть наряжать ёлка всё этот игрушка мишура по весь зала блииина это так круто
#  label: 1.0, prediction: 0.0
# text: rt войти в привычка ждать ты онлайн
#  label: 0.0, prediction: 1.0
# text: жвачка орбита — укреплять не только зуб но и парта в школа http t co
#  label: 1.0, prediction: 0.0
# text: даже я признавать наверное сей факт сцукий http t co
#  label: 0.0, prediction: 1.0
# text: julia_sirik guseyn73 за это активно банить добраться и до они
#  label: 1.0, prediction: 0.0
# text: пропасть до 9 ти а то нужно продолжать работать усилить я ждать толька тренер зануда как обычно
#  label: 1.0, prediction: 0.0
# text: окружающий мир доказывать я что внимание и любовь достойный только красивый девушка
#  label: 0.0, prediction: 1.0
# text: tafochka_best у ты показываться смайлик
#  label: 1.0, prediction: 0.0
# text: банан бананчик бля я быть очень долго это вспоминать
#  label: 1.0, prediction: 0.0
# text: просто ребёнок ещё или я старый для такой шутка
#  label: 0.0, prediction: 1.0
# text: rt я такой патриот что хотеть уехать из россия
#  label: 1.0, prediction: 0.0
# text: ekristisha надо стараться добиться bethanymotagiveaway
#  label: 1.0, prediction: 0.0
# text: ну как нагнать всё серия что пропустить
#  label: 1.0, prediction: 0.0
# text: самый тёплый место на земля сердце любимый самый хороший место на земля обьятие любимый самый сладкое на земля губа любимый
#  label: 0.0, prediction: 1.0
# text: ещё один помешанный на золото
#  label: 1.0, prediction: 0.0
# text: вы просто не представлять как сложно выбирать свой будущий профессия хотя наверное представлять
#  label: 1.0, prediction: 0.0
# text: aiperipups я свой перед я не должный быть стыдно
#  label: 1.0, prediction: 0.0
# text: блядь зачем я это увидеть на работа мой не понять
#  label: 1.0, prediction: 0.0
# text: а я даже не осмелиться подойти к они followback
#  label: 1.0, prediction: 0.0
# text: rt вчера захватить настолько что я весь ночь он читать оторваться не мочь теперь блин я это вылазить боком и я ве
#  label: 1.0, prediction: 0.0
# text: я бухать только в два случай когда у я день рождение и когда нет
#  label: 1.0, prediction: 0.0
# text: если я спрашивать как вы как у вы дело не надо спрашивать это у я
#  label: 0.0, prediction: 1.0
# text: хам
#  label: 1.0, prediction: 0.0
# text: rt malishevae этот заголовок похожий на групповой секс паровозик http t co
#  label: 0.0, prediction: 1.0
# text: загуглила фио и узнать что я находиться в федеральный розыск как должник б ть
#  label: 0.0, prediction: 1.0
# text: mileno4ka_mimi sfgo76 не за сила в движение
#  label: 1.0, prediction: 0.0
# text: сегодня быть чудесный вечер я не представлять как без вы быть проводить унылый будни отдельный спасибо romaaarioo за организация ты чудо
#  label: 0.0, prediction: 1.0
# text: посыпаться банковский система что же быть далёкий
#  label: 0.0, prediction: 1.0
# text: как сказать снова дружить я такой хотеть большой обнимашка
#  label: 1.0, prediction: 0.0
# text: у мы как кто уметь тот делать а кто не уметь тот учить и командовать
#  label: 0.0, prediction: 1.0
# text: рита тысяча а лера рить кул
#  label: 1.0, prediction: 0.0
# text: rt saalkano в лента исключительно
#  label: 0.0, prediction: 1.0
# text: le_viki dimaskamaz тёмный рыцарь посмотреть в немой саундтрек
#  label: 1.0, prediction: 0.0
# text: переться не дождаться когда брат впустить он в комната он решить прямо в коридор … http t co
#  label: 0.0, prediction: 1.0
# text: d00ker inpearly я школа закончить и это потом уже быть но не мешать встречаться и учиться и он и я потом пожениться
#  label: 1.0, prediction: 0.0
# text: вика удалиться из твиттер с кто я теперь вести упороть беседа
#  label: 0.0, prediction: 1.0
# text: мочь я скрытый или мочь социолог ну как объяснить кааак из миллион профессия выбрать тот самый
#  label: 0.0, prediction: 1.0
# text: avadoshka норма с я не лишний быть 1700 если не набрать 23 человек а если набрать 1400 в след пятница вечером
#  label: 1.0, prediction: 0.0
# text: в мир обязательно найтись тот рядом с который ты забыть о тот кто ты не когда не ценить а я уже найти
#  label: 1.0, prediction: 0.0
# text: лето кончиться это видно по резко увеличивать поток машина пробка расти
#  label: 0.0, prediction: 1.0
# text: rt veronicaputsy renatasvarovsky galinarogozina8 плохой дело плохой
#  label: 1.0, prediction: 0.0
# text: папа накричать на мама мама накричать на я а я в свой очередь накричать на сестра и от она я получить пизда в двойня
#  label: 1.0, prediction: 0.0
# text: ну ты обратно норма доехать прогульщик
#  label: 1.0, prediction: 0.0
# text: http t co искать себя кто найти вернуть
#  label: 1.0, prediction: 0.0
# text: мы лесби мы не интересно как ты в постеле
#  label: 1.0, prediction: 0.0
# text: timeout_msk значит пострадать не только москвич быть брат по несчастие с питерец и где там ещё в рф есть метро
#  label: 0.0, prediction: 1.0
# text: да это же весь лишь банан в мой мюсли
#  label: 0.0, prediction: 1.0
# text: tema_tomas оу сочувствовать надеяться всё проблёмкий близкий к нг испариться
#  label: 1.0, prediction: 0.0
# text: кто же виноватый что ты на столько тупой и по свой же вина остаться один
#  label: 1.0, prediction: 0.0
# text: rt ну воооот твиттер пархоменко большой не смешной
#  label: 0.0, prediction: 1.0
# text: неужели один dany_kvyat быть в 2014 боевой официально тест виталик остаться один место в вряд ли f1
#  label: 0.0, prediction: 1.0
# text: rt doktor_zlo_oo россиянин уверить что украинец на евромайдан вывести запад
#  label: 0.0, prediction: 1.0
# text: любить такой погода нехватать сейчас только любимый человек
#  label: 1.0, prediction: 0.0
# text: crazymofo_s ну трудно образ человек рисовать
#  label: 0.0, prediction: 1.0
# text: мама рассказать что в детство я всё время спасть теперь я знать что я уже тогда понимать что я быть очень не хватать в будущее
#  label: 1.0, prediction: 0.0
# text: у я тоже с горло что то не то давать выздоравливать
#  label: 1.0, prediction: 0.0
# text: как залечить душевный рана — нет такой средство http t co
#  label: 0.0, prediction: 1.0
# text: rt обидеть игорь но я и кайфовый
#  label: 1.0, prediction: 0.0
# text: rt niall_awww69 я тож в школа только на чувашский язык ты всё равно не знать о чем я
#  label: 1.0, prediction: 0.0
# text: юля круто фотка редактировать я не дать
#  label: 0.0, prediction: 1.0
# text: это вы ещё не знать как он сочинение писать про свинка
#  label: 1.0, prediction: 0.0
# text: проводить родитель и брат на отдых надеяться у они всё быть хорошо и отдых пройти на отлично быть скучать
#  label: 0.0, prediction: 1.0
# text: rt спасибо за fucking австрия fucking это небольшой поселение в австрия весь 150 житель
#  label: 0.0, prediction: 1.0
# text: rt а зачем я столько http t co
#  label: 1.0, prediction: 0.0
# text: масочок масочок для да здравствовать здоровый волос
#  label: 1.0, prediction: 0.0
# text: я знать всё ваш левый страница на я не в друга мочь я тож истерика тогда закатать и следить как ребёнок чесслово
#  label: 1.0, prediction: 0.0
# text: rt чувствовать ростов http t co
#  label: 1.0, prediction: 0.0
# text: rt boo_ohoo — мальчик какой у ты огромный что же ты в немой такой носить — цинизм тётенька цинизм и презерватив
#  label: 0.0, prediction: 1.0
# text: а сейчас я отправиться травить птица в лес надоесть они я http t co
#  label: 1.0, prediction: 0.0
# text: национальный референдум а только парламент содержать статья согласно
#  label: 1.0, prediction: 0.0
# text: rt shokirjonov muhrim
#  label: 1.0, prediction: 0.0
# text: оперативный служба рамблер восстановить мой почта луч добро
#  label: 1.0, prediction: 0.0
# text: rt как работаться джуик я час работать а потом 30 40 минута в общественный транспорт
#  label: 1.0, prediction: 0.0
# text: лентаа привет сегодня я оставаться с вы мама сказать что я мочь не идти в школа но только нужно быть я геометрия выучить
#  label: 1.0, prediction: 0.0
# text: я просто тая перед это запах не знать что мочь быть хороший это прямо капец
#  label: 1.0, prediction: 0.0
# text: вот и первый косяк 4 3 s note вылетать
#  label: 0.0, prediction: 1.0
# text: ладный ладный куда хороший орейро и если я когда нибыть и стать лесбиянка то только из за она
#  label: 1.0, prediction: 0.0
# text: rt allabanana olhovikova_an а ты где жить простить что не lt 3 я пить таблетка
#  label: 1.0, prediction: 0.0
# text: ниит теперь себя быть угнетать за это
#  label: 0.0, prediction: 1.0
# text: я не помнить точно но она старший год на два
#  label: 1.0, prediction: 0.0
# text: rt siconidezulo о что говорить мужчина — 1 5 час бесполезно потратить время хороший бы ведро
#  label: 0.0, prediction: 1.0
# text: а он измениться или я просто он начинать забывать
#  label: 0.0, prediction: 1.0
# text: нехер быть пропадать педро
#  label: 0.0, prediction: 1.0
# text: ну ну просто столько прогул у я за весь учёба не быть как в 9
#  label: 1.0, prediction: 0.0
# text: rt pyrevonarox есть такой незадача с экономный лампа
#  label: 0.0, prediction: 1.0
# text: обновить виртуалбокс до третий версия быстрый стать работать на глаз заметно
#  label: 1.0, prediction: 0.0
# text: bert_end я не умница прелесть это весь лишь пробный егэ впереди настоящий а это в сто раз плохой
#  label: 1.0, prediction: 0.0
# text: это пустяк я каждый день такой расстояние преодолевать на работа и обратно
#  label: 1.0, prediction: 0.0
# text: rt kofakoferepo отлично it правда случайно набрести на pidgin webkit давно
#  label: 0.0, prediction: 1.0
# text: жирный это когда в примерочный не влезать так что всё пучок не жирный ты женька
#  label: 1.0, prediction: 0.0
# text: как представлять свой кошка в нарнии прям зависть брать
#  label: 0.0, prediction: 1.0
# text: мама завидовать что я деньга на счёт кидать а она нет
#  label: 1.0, prediction: 0.0
# text: k1drauhl69 бибер собака не жирно ли у я самый серьёзный отношение ток с книга фанфиковы быть
#  label: 0.0, prediction: 1.0
# text: нe нe c мёд
#  label: 1.0, prediction: 0.0
# text: 00darya воу а у я с открываться сонный глаз
#  label: 1.0, prediction: 0.0
# text: закончить ходить я смешно мягко говорить x нога распухнуть как у утопленник
#  label: 1.0, prediction: 0.0
# text: а как выйти гулять то думать с лиза что быть скучно и не кто не прийти мы глубоко ошибаться
#  label: 1.0, prediction: 0.0
# text: и нахуй этот репа мочь художник из я норма выйти
#  label: 1.0, prediction: 0.0
# text: наслать в саратовский область в какой то село прислать забрать телефон
#  label: 1.0, prediction: 0.0
# text: rt xvbrx spb_citizen да вот один я сейчас проповедовать о русский кацап ржа
#  label: 1.0, prediction: 0.0
# text: зато они делать человек больно и это круто
#  label: 1.0, prediction: 0.0
# text: к вторник стихотворение к пятница песня к суббота письмо татьяна к онегин сложно http t co
#  label: 0.0, prediction: 1.0
# text: житель посёлок чтить память воевать за они боец куча мусор около памятник честь и хвала http t co
#  label: 0.0, prediction: 1.0
# text: santairis стареть http t co
#  label: 1.0, prediction: 0.0
# text: plantom_kam а без они просто мудак быть поход
#  label: 1.0, prediction: 0.0
# text: что за третий год магистратура мы что то пропустить
#  label: 1.0, prediction: 0.0
# text: orgil31 вакцина нэртэя хор монгол улс
#  label: 0.0, prediction: 1.0
# text: хотеть на нг купить 3 больший набор наггетс как какой то мужик лето в макдак
#  label: 1.0, prediction: 0.0
# text: deltakilo не выгодный с в за близкий ездить быть
#  label: 1.0, prediction: 0.0
# text: ахахах сейчас ещё и в кино уснуть
#  label: 0.0, prediction: 1.0
# text: с лето составлять список тот что хотеть прочитать прочитать всё нужно срочно искать что нибыть новенький
#  label: 0.0, prediction: 1.0
# text: а у я так этот дневник для себя большой в для общение твиттер
#  label: 1.0, prediction: 0.0
# text: да я уже видеть как по я симпотный такой а когда результат известный быть
#  label: 1.0, prediction: 0.0
# text: сейчас мой сайт в буквальный смысл я кормить ням вксный калбас
#  label: 1.0, prediction: 0.0
# text: вот это ты внатура загнуть
#  label: 0.0, prediction: 1.0
# text: rt dazibohuxari кто помнить такой мороженое сегодня увидеть в магазин настолько удивиться что купить не то в время детство эт
#  label: 0.0, prediction: 1.0
# text: ekaterinaa33 тип
#  label: 1.0, prediction: 0.0
# text: ah ah ah ah ah — тут слишком горячо з кстати чай так и не сделать сам себя сасай http t co
#  label: 0.0, prediction: 1.0
# text: як поставитя цю на юп в тві ну мож
#  label: 0.0, prediction: 1.0
# text: ya_aristokratka да что он быть ну сбегать пара раз ты не убыть
#  label: 1.0, prediction: 0.0
# text: ахахи красава у мы бывать за это предок вызывать поэтому мы делать
#  label: 0.0, prediction: 1.0
# text: я тоже хотеть посмотреть
#  label: 1.0, prediction: 0.0
# text: не поверить у ты внешность вообще не напоминать наличие бабушка по нужный линия
#  label: 1.0, prediction: 0.0
# text: разве так трудно просто зайти на 5 минута в онлайн и сказать что с ты всё хорошо я же волноваться
#  label: 0.0, prediction: 1.0
# text: сушить курочка пивко вот что я любить
#  label: 1.0, prediction: 0.0
# text: это ты так лыжа отвечать на нок нок
#  label: 1.0, prediction: 0.0
# text: rt takanorimitsuki один предложение похерить я настроение да это талант
#  label: 0.0, prediction: 1.0
# text: а теперь серьёзно космический батюшка http t co материться не быть всё что хотеть излить и стереть http t co
#  label: 0.0, prediction: 1.0
# text: rt dany_belik есть момент который хотеться растянуть на весь жизнь и есть человек который хотеться видеть всегда
#  label: 1.0, prediction: 0.0
# text: этот малыш большой шалунишка очень активный и ни раз не грустный кот а фотографировать он оой как … http t co
#  label: 1.0, prediction: 0.0
# text: ernestmakarenko эрнест сколько можно конь устать
#  label: 1.0, prediction: 0.0
# text: брат с девушка праздновать мама в друг место праздновать быть и бабушка тоже юлька дом один
#  label: 0.0, prediction: 1.0
# text: такой же ерунда я просто дикий балда
#  label: 0.0, prediction: 1.0
# text: я злиться на ты не за то что ты сделать а за то что ты я соврать хороший бы правда сказать ага сказать правда такой же пиздюля получить
#  label: 0.0, prediction: 1.0
# text: rt всё воскресение провести дом а один человек быть в мак и видеть а у даша быть истерика
#  label: 0.0, prediction: 1.0
# text: я спать завтра сложный день потому что без надеяться я справиться
#  label: 1.0, prediction: 0.0
# text: мой дедушка в дед мороз переодеваться
#  label: 0.0, prediction: 1.0
# text: думать что идея не плохой но нужно за суповой и молочко сходить
#  label: 0.0, prediction: 1.0
# text: завтра блин в настольный игра идти играть судьба только сегодня с друг о сбор человек говорить а тут сотрудничать мутить секта
#  label: 1.0, prediction: 0.0
# text: фотка с мама — очень жаль но у я нет нормальный фотка с мама http t co
#  label: 1.0, prediction: 0.0
# text: продаваться авто недорого http t co
#  label: 1.0, prediction: 0.0
# text: rt solo5_7 like_linu vezhlivyyenot добро вы
#  label: 1.0, prediction: 0.0
# text: я хотеть 32 и чтобы солнце пекло и хотеть
#  label: 1.0, prediction: 0.0
# text: любить ты родный жаль что сейчас проводить маленький время вместе чем ранний но ты по прежний я очень дорога lt 3 http t co
#  label: 1.0, prediction: 0.0
# text: че это поработать я до сей пора работать я пошутить пытаться юмор у я такой не судить строго
#  label: 0.0, prediction: 1.0
# text: я уже ждать не дождаться этот каникулы
#  label: 1.0, prediction: 0.0
# text: я 65 скрин в поезд клеить а что ты знать о боль
#  label: 1.0, prediction: 0.0
# text: rt icarelajno животное покинуть автобус не не я я ещё ехать и ехать а вот с выйти
#  label: 1.0, prediction: 0.0
# text: у вендёрса быть такой фильм http t co
#  label: 0.0, prediction: 1.0
# text: компонент полностью отладить отшлифовать и блин уже кодить не хотеться это самый интересно что я сделать
#  label: 1.0, prediction: 0.0
# text: в командировка её отправить в разъезд по разный город
#  label: 0.0, prediction: 1.0
# text: сидеть и ждать сидеть и ждать сидеть и ждать заявление федеральный комитет открытый рынок
#  label: 0.0, prediction: 1.0
# text: rt dermisson m_galustyan это я ты поздравлять 1 в европа быть представить серия где ты весь поливать говно
#  label: 1.0, prediction: 0.0
# text: rt obnuli отношение пережить расстояние вечность
#  label: 1.0, prediction: 0.0
# text: как и в прошлый год большой привет ук
#  label: 0.0, prediction: 1.0
# text: на новый место работа ещё нет столовая приходиться носить еда с себя http t co
#  label: 0.0, prediction: 1.0
# text: как же приятно слышать такой слово после такой не ты должный обижаться а мы
#  label: 0.0, prediction: 1.0
# text: lentaruofficial это же святой софия сахарный кремль же
#  label: 1.0, prediction: 0.0
# text: fuckin_sadness а я ещё и рука ломать в 3 класс подскользнуться по дорога в школа
#  label: 1.0, prediction: 0.0
# text: rt мила и я очень радовать то что когда к он подходить кто то он плакать а когда я улыбаться
#  label: 1.0, prediction: 0.0
# text: настя понять а он всегда хотеть быть первый сперва потом план нерв
#  label: 1.0, prediction: 0.0
# text: didkovskiy я тоже скоро предстоять наркоз за руль не мешать получаться рот говорить
#  label: 0.0, prediction: 1.0
# text: rt увлечься тут игра
#  label: 0.0, prediction: 1.0
# text: поход следующий раз я тоже не говорить результат рт
#  label: 1.0, prediction: 0.0
# text: мочь продолжать жить и встречаться с мамка и не отпрашиваться
#  label: 1.0, prediction: 0.0
# text: только однокурсник мочь позвонить в в четверг потому что знать что спать перед интерьер ты не быть
#  label: 1.0, prediction: 0.0
# text: какой размер грудь — я забыть http t co
#  label: 0.0, prediction: 1.0
# text: rt karandash_87 “ crazy_kutas не пропустить http t co ” klirik80 juljulianapai второй попытка
#  label: 1.0, prediction: 0.0
# text: офигенский мультик весь вечер смотреть надька простить
#  label: 1.0, prediction: 0.0
# text: кто что а я надо найти конференция с нодар
#  label: 1.0, prediction: 0.0
# text: ахуенный день за последний время я избавиться от цепь что я дождь туман кофе карамельный театр музыка петь
#  label: 1.0, prediction: 0.0
# text: eun_hae_shipper милый почм написать
#  label: 1.0, prediction: 0.0
# text: всё гулять весь весело а я один дом киснуть
#  label: 0.0, prediction: 1.0
# text: с я часик 30 полежать ты хотеть
#  label: 1.0, prediction: 0.0
# text: анекдот прикол ничто так не стимулировать на уборка как слово человек через полчасика мы у ты
#  label: 1.0, prediction: 0.0
# text: ааа круто чувак а я хотеть торба с марс
#  label: 0.0, prediction: 1.0
# text: и вот мой твит я просрало свой 3000 тви
#  label: 1.0, prediction: 0.0
# text: мы она вообще никто не отдать – она мы сам нужный
#  label: 1.0, prediction: 0.0
# text: voronin_wi я они не смотреть же не в курс я только читать онлайн по понедельник
#  label: 1.0, prediction: 0.0
# text: rt в сбу читать уметь пусть конституция взять и найти ответ кто в украина есть власть євромайдан live at http t co c …
#  label: 0.0, prediction: 1.0
# text: rt маленький история о сон от лента http t co
#  label: 1.0, prediction: 0.0
# text: polina984 как миленько у мы тоже такой быть только мальчик плакать потому что у он дедушка умереть
#  label: 1.0, prediction: 0.0
# text: как я ты понимать до нг самый ад даже сессия не такой страшный там экзамен маленький хдд да уж только не пропадать совсем
#  label: 1.0, prediction: 0.0
# text: ну ты какашка ❤️ это не я это инет а я не разлюбить ты
#  label: 1.0, prediction: 0.0
# text: rt вот ранний фоткаться на мобильник выставить в одноклассник контакт и нормально а сейчас
#  label: 1.0, prediction: 0.0
# text: если сейчас не проснуться то сегодня уже не проснуться
#  label: 1.0, prediction: 0.0
# text: ну не красавица ну пожалуйста ну пальчик один http t co
#  label: 0.0, prediction: 1.0
# text: любовь любовь а всё равна ов 4 часть сумерка они потрахаться
#  label: 1.0, prediction: 0.0
# text: действительно странный обстоятельство преследовать я
#  label: 1.0, prediction: 0.0
# text: встречаться мочь быть — нет http t co
#  label: 0.0, prediction: 1.0
# text: я же недавно сниться что я быть в банда
#  label: 1.0, prediction: 0.0
# text: rt megerra пока вы спать ваш телефон мочь обновить твиттер хороший бы кофе варить
#  label: 0.0, prediction: 1.0
# text: rt lesik_2804 она не хотеть я он дарить alyonafateeva http t co
#  label: 1.0, prediction: 0.0
# text: ну правильно на крайняк уже лето переживать не прийтись
#  label: 1.0, prediction: 0.0
# text: сам вы шахтёр http t co
#  label: 0.0, prediction: 1.0
# text: я перебраться на этот станция после чистка ff
#  label: 0.0, prediction: 1.0
# text: он сказать что сфоткаяться только не он
#  label: 1.0, prediction: 0.0
# text: поручить почистить машина от снег сломать дворник
#  label: 0.0, prediction: 1.0
# text: ты и оригами признаться я ранний быть мнение что ты не хватить и на час подобный мелкий работа
#  label: 1.0, prediction: 0.0
# text: sofa_zelik tetatet1212 да уж но это для польза терпеть сила вы и мужество приятный вечер
#  label: 0.0, prediction: 1.0
# ...
# text: ты думать что я быть плакать рыдать ночью в подушка не быть это похуизм не лечиться http t co
#  label: 1.0, prediction: 0.0
# text: t_felg вот мужчина мой мечта http t co ну ни капелька на он он не похожий не травить
#  label: 1.0, prediction: 0.0
# text: не в этот случай можно жмякать а потом уж и ctrl enter только в тип форма нужный не весь
#  label: 1.0, prediction: 0.0
# text: и судить по весь в понедельник я быть пить чаёк
#  label: 1.0, prediction: 0.0
# text: перчатка виртуальный реальность — девайс будущее хотя скорее уже далёкий прошлое
#  label: 0.0, prediction: 1.0
# text: весь то 7 ❄ а что то морозить не на шутка http t co
#  label: 0.0, prediction: 1.0
# text: немного горький правда http t co
#  label: 0.0, prediction: 1.0
# text: severinina3 asya_vrode молчать просто молчать 0000
#  label: 1.0, prediction: 0.0
# text: вы я кидануль
#  label: 0.0, prediction: 1.0
# text: я сегодня в удар 10 страница конспект по биология пойти уже
#  label: 1.0, prediction: 0.0
# text: на начинать рот ни раз в жизнь за свой год я не хотеть сказать отвалить сучка он мой
#  label: 1.0, prediction: 0.0
# text: cybermen_oleg думать у ты выйти хороший оценка я никогда лола даже стремный как то как будто
#  label: 0.0, prediction: 1.0
# text: если я сейчас купить киндёр и я попасться фигурка который уже быть то начаться пиздец
#  label: 1.0, prediction: 0.0
# text: rt дурацкий привычка везде ставить разный пароль и они забывать
#  label: 0.0, prediction: 1.0
# text: rt ребёнок должный учиться одеваться сам teamfollowback
#  label: 1.0, prediction: 0.0
# text: иногда нужно просто замолчать пропасть и молча понаблюдать за человек какой удивление иногда на я на ходить на что способный мой окружение
#  label: 1.0, prediction: 0.0
# text: вот она мы то
#  label: 1.0, prediction: 0.0
# text: maryanadavydova прелестно но я зануда не любить ты бы понравиться один мой сотрудник лешка очень красивый но зануда
#  label: 0.0, prediction: 1.0
# text: это да … в произвести звук и ты прийти email
#  label: 0.0, prediction: 1.0
# text: везти ты я б твой валенок у мы сегодня 20 замёрзлый как
#  label: 0.0, prediction: 1.0
# text: русланчик уйти из жизнь 14 11 2012 мы ты любим и помнить
#  label: 0.0, prediction: 1.0
# text: нельзя так просто сделать идеальный подарок
#  label: 0.0, prediction: 1.0
# text: rt bilanofficial трио безысходность http t co
#  label: 1.0, prediction: 0.0
# text: juliascherbet качество просто срань да и вообще больший ждать
#  label: 0.0, prediction: 1.0
# text: rt уолл
#  label: 1.0, prediction: 0.0
# text: хотеть чтоб на интернет у я оставаться маленький весь время teamfollowback
#  label: 1.0, prediction: 0.0
# text: хахахха с от что угодный отвыкнуть можно
#  label: 1.0, prediction: 0.0
# text: ждать любимый скорый бы он прийти http t co
#  label: 0.0, prediction: 1.0
# text: beetle_juice69 я отлично ты из за прививка болеть да
#  label: 1.0, prediction: 0.0
# text: america__la да вы что
#  label: 0.0, prediction: 1.0
# text: в последний момент вспомнить что будильник у мы стоять на 4 30 проснуться в такой время не самый большой удовольствие
#  label: 1.0, prediction: 0.0
# text: buttersmai остаться выйти с у ск не задумываться
#  label: 1.0, prediction: 0.0
# text: нееет я это не из песня взять
#  label: 1.0, prediction: 0.0
# text: у мина хо даже в средневековый дорама модный причёска вот такой он наш
#  label: 1.0, prediction: 0.0
# text: мой подарок вадик задерживать пока на час зато дать талон на международный аэропорт … http t co
#  label: 0.0, prediction: 1.0
# text: ясный дело а я даже не знать что но что то быть смотреть определённо
#  label: 1.0, prediction: 0.0
# text: но я так ждать этот суббота чтоб на каток пойти
#  label: 1.0, prediction: 0.0
# text: юра съесть всё вкусняшка
#  label: 0.0, prediction: 1.0
# text: rt sfgo76 страна должный знать свой герой в лицо опять с народ не угодить http t co http t co
#  label: 0.0, prediction: 1.0
# text: я ващий пропустить это мимо ухо к чёрт этот тема че в 9 серия они за хуйня сотворить
#  label: 1.0, prediction: 0.0
# text: а я сделать это острый стадия сразу поймать всё необходимый сделать я сегодня крутой как никогда
#  label: 1.0, prediction: 0.0
# text: rt жд гореть http t co
#  label: 1.0, prediction: 0.0
# text: как я мочь быть настроить если я знать что сегодня ппц быть ещё и маман в ночь
#  label: 1.0, prediction: 0.0
# text: rt n_barmaleykina че за фигня твориться с сиська мама дядя фёдор http t co
#  label: 1.0, prediction: 0.0
# text: нет в они никакой толк увы и это только говорить что бросить трудно на сам дело нет просто переставать и всё
#  label: 1.0, prediction: 0.0
# text: бляха муха то капец то капец http t co
#  label: 1.0, prediction: 0.0
# text: пожаловаться никита вк надеяться скоро зайти 3
#  label: 0.0, prediction: 1.0
# text: ambicj как ты угадать я именно так и делать ранний пока не встретить молиться чело на мусульманский жутко испугаться и большой не ходить
#  label: 1.0, prediction: 0.0
# text: xenia_sobchak получиться путин п н х это такой троллинг
#  label: 0.0, prediction: 1.0
# text: digital_phobia эм если я он не видеть значит он нет
#  label: 1.0, prediction: 0.0
# text: у ты уже есть официальный приложение ask fm для android — забрать мой андроид http t co
#  label: 0.0, prediction: 1.0
# text: помнить купить кольцо best friends я спросить для кто второе а ты ответить что не знать хотя сам отдать он арин
#  label: 0.0, prediction: 1.0
# text: msdarren16 madmein досмотреть это нечто офигительный
#  label: 1.0, prediction: 0.0
# text: миссия это предназначение а она на главный страница сайт мади сформулировать как цель деятельность
#  label: 0.0, prediction: 1.0
# text: я сегодня качать в всё сторона настроение мрмрмр
#  label: 1.0, prediction: 0.0
# text: lasskka воспользоваться сейчас же
#  label: 1.0, prediction: 0.0
# text: kotpolozova постоянно ругаться что тип сервис не в порядок вот же купить баба
#  label: 0.0, prediction: 1.0
# text: вчера посмотреть сериал тайна мег доставить слово не быть один эмоция
#  label: 1.0, prediction: 0.0
# text: я присниться что к я принц на конь ворон и помыть весь посуда
#  label: 0.0, prediction: 1.0
# text: проснуться умыться открывать холодильник и брать кефир а сверху стоить коробка с яйцо коробка с яйцо на пол а я с кефир утро добрый
#  label: 0.0, prediction: 1.0
# text: nevedom2008 привет если есть лишний код на подарить плз очень хотеться он не мочь уже который день выловить код просить
#  label: 0.0, prediction: 1.0
# text: ты видно совсем пофига то что я ты говорить
#  label: 0.0, prediction: 1.0
# text: любить он но о это сказать как то он не решаться
#  label: 1.0, prediction: 0.0
# text: иногда любить побродить по простор ануть предприятие и от душа цинично поржать
#  label: 0.0, prediction: 1.0
# text: с понедельник начать баловаться с studio решить попробовать часть работа делать в vs
#  label: 0.0, prediction: 1.0
# text: зелёный гарри поттероман http t co
#  label: 0.0, prediction: 1.0
# text: а господь слава
#  label: 1.0, prediction: 0.0
# text: rt j_linka блиннна как же я она любить ♥ но уже забыть как там играть back_to_90th девчонка помнить этот игра http t co if …
#  label: 0.0, prediction: 1.0
# text: не сметь называть зефирка они же по вкус абсолютно разный
#  label: 0.0, prediction: 1.0
# text: green_killj0y у мы тоже еле еле снег лежать пусть бы выпасть уже
#  label: 1.0, prediction: 0.0
# text: с утро я нехило вставить и я впасть в депрессия длина в пять час
#  label: 1.0, prediction: 0.0
# text: rt только в я мочь создать женщина мечта http t co
#  label: 0.0, prediction: 1.0
# text: ох прикрыть этот ваш рунет среднерусский если и далёкий так дело пойти
#  label: 0.0, prediction: 1.0
# text: тяжко постараться успеть посмотреть на большой экран это что то с чем то
#  label: 0.0, prediction: 1.0
# text: korobkov в что проблема знать такой
#  label: 1.0, prediction: 0.0
# text: поход я действительно один кто не прогуливать даже прогуливать
#  label: 1.0, prediction: 0.0
# text: эпопея начаться маша вчера сказать что если славик не поехать то и она не поехать тип слава там быть с они спокойный
#  label: 0.0, prediction: 1.0
# text: тёплый ты задолбать с свой тёплый
#  label: 1.0, prediction: 0.0
# text: я хотеть на море на большой глубокий необъятный а то надоесть в душа купаться http t co
#  label: 1.0, prediction: 0.0
# text: в 12 00 послание федеральный собрание не забыть
#  label: 1.0, prediction: 0.0
# text: грызлов скучный всё что он говорить подпадать под определение имитационный демократия он про оппозиция он про к
#  label: 0.0, prediction: 1.0
# text: rt alex_zhzhet andreyalenkuts sonyakazhan да но я на немой не ездить ни раз на чистый пруд который до чистка называться поганый п …
#  label: 1.0, prediction: 0.0
# text: хотеть завтракать быть пойти кушать вкусняшка вместо пара но она совестливый
#  label: 0.0, prediction: 1.0
# text: верный и быть они не ладный не давать мы забить
#  label: 1.0, prediction: 0.0
# text: мороз отжечь конечно в самара но кстати как то неудивительный
#  label: 0.0, prediction: 1.0
# text: rt eldarmurtazin а да совсем забыть сказать в windows phone 9 не быть плитка и такой интерфейс а так долго убеждать в он величие
#  label: 1.0, prediction: 0.0
# text: мама с папа собираться на новый год в нск плакать с янка
#  label: 1.0, prediction: 0.0
# text: я никогда не игнорать человек просто уходить из они жизнь
#  label: 1.0, prediction: 0.0
# text: да я самый везучий человек на планета нужно решить не менее 80 а у я 79
#  label: 0.0, prediction: 1.0
# text: euromaidan дебил человек только большой прийти в ярость
#  label: 0.0, prediction: 1.0
# text: сказочно в 20 уснуть как сурок после обед проснуться принять душа вобщий спасть весь день
#  label: 1.0, prediction: 0.0
# text: слушать scratch — детский мир аж мурашки по кожа если вдуматься то жутко становиться
#  label: 1.0, prediction: 0.0
# text: так вот оказываться что парень нужно эх а я как то не к тот стремиться с надо всё менять
#  label: 1.0, prediction: 0.0
# text: веселух найтись месяц где то пропадать http t co
#  label: 1.0, prediction: 0.0
# text: rt aizadolmatova я просто хотеть он нравиться
#  label: 0.0, prediction: 1.0
# text: salty__1970 готовый всё не склеить они теперь я хотя что то они теперь я нах слать
#  label: 1.0, prediction: 0.0
# text: блииина почему не в весь магазин есть такой штука что бы оплачивать с карточка это не честно помнить как я мучалася
#  label: 1.0, prediction: 0.0
# text: а от что такой пристальный внимание к rogozin
#  label: 1.0, prediction: 0.0
# text: verrraverrra simonowalexej alendmitrieva опять же сила привычка
#  label: 1.0, prediction: 0.0
# text: почему бы и не свой пупсик http t co
#  label: 1.0, prediction: 0.0
# text: dominobank и тут я забыть зачем прийти http t co
#  label: 1.0, prediction: 0.0
# text: думать они это прочитать и поторопиться
#  label: 1.0, prediction: 0.0
# text: у мы тоже мороз до 5 градус погода замечательный
#  label: 1.0, prediction: 0.0
# text: ого неожиданно мда значит прийтись ещё гуглить глазеть обзор
#  label: 1.0, prediction: 0.0
# text: tdanylenko вывод простой забить он на майдан и не бояться большой ничего
#  label: 0.0, prediction: 1.0
# text: ты кто нибыть убить несколько полицейский а человек нет только полицейский диалог в фильм всегда
#  label: 1.0, prediction: 0.0
# text: rt патихардить с на урок география в столовая за 9 год учёба такой впервые слоупка http t co
#  label: 1.0, prediction: 0.0
# text: я тоже так думать что чуть длинный просто у я когда то быть каре и сказать что бы ужасно хотя я сейчас поменяться мб пойти
#  label: 1.0, prediction: 0.0
# text: ты сам согласиться на спор извинить
#  label: 0.0, prediction: 1.0
# text: ну а как же это обязательный часть
#  label: 1.0, prediction: 0.0
# text: но мы ничто не остановить хд только путь несколько иной
#  label: 1.0, prediction: 0.0
# text: фильм снятой в район один бабка не выдержать жара этот место сказать это не а что переводиться как ад
#  label: 1.0, prediction: 0.0
# text: ну ты мило а я не очень быть в глаз у родный мать шлюха блин
#  label: 1.0, prediction: 0.0
# text: м да только что обнаружить что мочь рулить плеер из редактор который часто пользоваться вот почему я до сей пора так
#  label: 1.0, prediction: 0.0
# text: rt http t co а счастие быть так близко
#  label: 0.0, prediction: 1.0
# text: rt zywahaxowebe просто он на я подписать а я вчера пошалить немножко матрица следить за ты
#  label: 1.0, prediction: 0.0
# text: rt l_o_o_k_o_u_t всё частый убеждаться что мы мий и похожий до жуть lt 3 дружба сходство
#  label: 0.0, prediction: 1.0
# text: ч билүү хэдэн жилийна өмнө л очиж байсана
#  label: 0.0, prediction: 1.0
# text: без я ты никто сказать интернет компьютер
#  label: 1.0, prediction: 0.0
# text: ящитая всё правильно сделать я как то сложно что то выбрать всё ржачной бложик с дорама опять же
#  label: 1.0, prediction: 0.0
# text: donpetakov некоторый человек если бы не отвратительный характер не стать бы великий
#  label: 1.0, prediction: 0.0
# text: уничтожить под орех ващий не напрягаться
#  label: 1.0, prediction: 0.0
# text: прогресс я сегодня о немой думать весь 8 раз сомнительный достижение
#  label: 0.0, prediction: 1.0
# text: ответить или нет вот в чем вопрос а пока что я спать 3
#  label: 1.0, prediction: 0.0
# text: шитый если полететь прошить что оставаться делать х
#  label: 0.0, prediction: 1.0
# text: я не сказать ты результат как настоящий друг
#  label: 1.0, prediction: 0.0
# text: даже такой маленький комиссия я выводить http t co
#  label: 0.0, prediction: 1.0
# text: malakhovaanna посмотреть а быть бороться с это явление в мой дом
#  label: 1.0, prediction: 0.0
# text: нуууууа угадывать уже в гугл вбить картинка или что
#  label: 0.0, prediction: 1.0
# text: видеть он закрытый http t co
#  label: 0.0, prediction: 1.0
# text: иногда нужно и о себя заботиться потому что если ты быть плохо то остальной хороший не быть
#  label: 0.0, prediction: 1.0
# text: героинашеговременить http t co вопрос нет друг хотя очень открытый в это весь и беда
#  label: 0.0, prediction: 1.0
# text: никогда не думать что так обрадоваться бутерброд х второй раз этот парень я спасать 3
#  label: 1.0, prediction: 0.0
# text: снег точно из израиль к мы пожаловать мелкий какой то
#  label: 0.0, prediction: 1.0
# text: потому что я так хотеть не новый но я нравиться
#  label: 1.0, prediction: 0.0
# text: rt kolaboks пытаться спасти рабочий фотоаппарат нужный спец он больной омск фото pr http t co
#  label: 0.0, prediction: 1.0
# text: черепашка кушать помидорк http t co
#  label: 1.0, prediction: 0.0
# text: tanyakalugina потому что жить в томск
#  label: 0.0, prediction: 1.0
# text: rusrusdada с такой накрывать на долго бояться к новый год не отпустить привет
#  label: 1.0, prediction: 0.0
# text: diqoily я даже приехать бог большой с транспорт как и вчера не уехать трамвай переполнить дорога даже не убирать поэтому всё на
#  label: 1.0, prediction: 0.0
# text: почему ты такой тупой — сам интересно http t co
#  label: 1.0, prediction: 0.0
# text: ооо я не представлять что ты хотеть устроить
#  label: 1.0, prediction: 0.0
# text: rt oksana748 я тоже хотеть помнить тот зима быть очень круто
#  label: 0.0, prediction: 1.0
# text: я как голубь быть хавать пока не умереть
#  label: 1.0, prediction: 0.0
# text: rt dj__de dallonurie конечно но нужно ещё грамотно он большой время уйти но результат стоить тот
#  label: 1.0, prediction: 0.0
# text: у весь есть план на нг
#  label: 1.0, prediction: 0.0
# text: nastiathisiswar karry_blake она я не дрыщ я жир ахах
#  label: 1.0, prediction: 0.0
# text: alexa4o гив ми ✋ просто мы победитель по жизнь хах
#  label: 0.0, prediction: 1.0
# text: elennevsk молодец я там написать ты что не отвечать
#  label: 1.0, prediction: 0.0
# text: rt rt 18moree а что давать вывести сиськаneverdie
#  label: 1.0, prediction: 0.0
# text: чертовый дюжина 13 молодой актриса в главный событие сезон http t co
#  label: 0.0, prediction: 1.0
# text: оказываться у мы работать три повар участвовать в заправка
#  label: 0.0, prediction: 1.0
# text: заварить зелёный чаёк с мятый вкусняша
#  label: 1.0, prediction: 0.0
# text: чем близкий к он тем сердце биться частый бассейн
#  label: 1.0, prediction: 0.0
# text: хотеть признаться что я ужасно можно сказать до смерть любить певец и он звать знать ты самый хороший
#  label: 1.0, prediction: 0.0
# text: rt ну да я нереально целоваться и что ты всё равно это никогда не обломиться
#  label: 1.0, prediction: 0.0
# text: смысл быть в угон и сход с рельс ну и доехать до др город можно быстро
#  label: 1.0, prediction: 0.0

# %% [markdown]
# С леммами повышается качество классификации, что ожидаемо, так как теперь у него больше данных про конкретное слово, потому что токены объединились в меньшее количество лемм
#
# В основном модель ошибается в сложных случаях (например, "победитель по жизни"), где присутствует ирония или сарказм. Так как твиты короткие сами по себе, то модели сложно понять из малого контекста посыл

# %% [markdown]
# # Часть II.
#
# Зададим датасет с двумя выходами:

# %%
class TwoWayTweetsDataset(Dataset):

    def __init__(self, dataset, word2id, symbol2id, DEVICE):
        self.dataset = dataset['text'].values
        self.word2id = word2id
        self.symbol2id = symbol2id
        self.length = dataset.shape[0]
        self.target = torch.Tensor(dataset['tone'].values)
        self.device = DEVICE

    def __len__(self): #это обязательный метод, он должен уметь считать длину датасета
        return self.length

    def __getitem__(self, index): #еще один обязательный метод. По индексу возвращает элемент выборки
        tokens = self.tokenize(self.dataset[index]) # токенизируем
        symbols = list(self.dataset[index])
        ids = torch.LongTensor([self.word2id[token] for token in tokens if token in self.word2id])
        symbol_ids = torch.LongTensor([self.symbol2id[symbol] for symbol in symbols if symbol in self.symbol2id])
        y = self.target[index]
        return ids, symbol_ids, y
    
    def preprocess(self, text):
        tokens = text.lower().split()
        tokens = [token.strip(punctuation) for token in tokens]
        tokens = [token for token in tokens if token not in punctuation]
        return tokens

    def tokenize(self, text):
        tokens = [token for token in tokenizer.tokenize(text.lower()) if token not in punctuation]
        #lemmas = [morph.parse(token)[0].normal_form for token in tokens if token not in punctuation]
        return tokens

    def collate_fn(self, batch): #этот метод можно реализовывать и отдельно,
    # он понадобится для DataLoader во время итерации по батчам
      ids, symbol_ids, y = list(zip(*batch))
      padded_ids = pad_sequence(ids, batch_first=True).to(self.device)
      padded_symbol_ids = pad_sequence(symbol_ids, batch_first=True).to(self.device)
      y = torch.Tensor(y).to(self.device)
      return padded_ids, padded_symbol_ids, y

# %%
class MixedModel(nn.Module):
    
    def __init__(self, word_vocab_size, symbol_vocab_size, embedding_dim):
        super().__init__()
        self.word_embedding = nn.Embedding(word_vocab_size, embedding_dim)
        self.symbol_embedding = nn.Embedding(symbol_vocab_size, embedding_dim)
        self.linear = nn.Linear(in_features=embedding_dim, out_features=10)
        self.bigrams = nn.Conv1d(in_channels=embedding_dim, out_channels=10, kernel_size=2, padding='same')
        self.trigrams = nn.Conv1d(in_channels=embedding_dim, out_channels=8, kernel_size=3, padding='same')
        self.pooling = nn.MaxPool1d(kernel_size=2, stride=2)
        self.relu = nn.ReLU()
        self.hidden = nn.Linear(in_features=28, out_features=1)
        self.dropout = nn.Dropout(p=0.5)
        self.out = nn.Sigmoid()

    def forward(self, word, symbol):
        word_embedded = self.word_embedding(word)
        sentence = torch.mean(word_embedded, axis=1)
        linear = self.linear(sentence)
        symbol_embedded = self.symbol_embedding(symbol)
        embedded = symbol_embedded.transpose(1,2)
        feature_map_bigrams = self.pooling(self.relu(self.bigrams(embedded)))
        feature_map_trigrams = self.pooling(self.relu(self.trigrams(embedded)))
        pooling1 = feature_map_bigrams.max(2)[0] 
        pooling2 = feature_map_trigrams.max(2)[0]
        concat = torch.cat((pooling1, pooling2, linear), 1)
        logits = self.hidden(concat)
        logits = self.out(logits)      
        return logits

# %%
train_dataset = TwoWayTweetsDataset(train_sentences, lemma2id, symbol2id, DEVICE)
train_sampler = RandomSampler(train_dataset)
train_iterator = DataLoader(train_dataset, collate_fn = train_dataset.collate_fn, sampler=train_sampler, batch_size=512)
val_dataset = TwoWayTweetsDataset(val_sentences, lemma2id, symbol2id, DEVICE)
val_sampler = SequentialSampler(val_dataset)
val_iterator = DataLoader(val_dataset, collate_fn = val_dataset.collate_fn, sampler=val_sampler, batch_size=512)

# %%
def train(model, iterator, optimizer, criterion, metric):
    print('Training...')
    epoch_loss = 0 # для подсчета среднего лосса на всех батчах
    epoch_metric = 0
    model.train()

    for i, (texts, symbols, ys) in enumerate(iterator): #итерируемся по батчам
        optimizer.zero_grad()  #обнуляем градиенты
        preds = model(texts, symbols).squeeze()  #прогоняем данные через модель
        loss = criterion(preds, ys) #считаем значение функции потерь  
        loss.backward() #считаем градиенты  
        optimizer.step() #обновляем веса 
        epoch_loss += loss.item() #сохраняем значение функции потерь
        batch_metric = metric(preds.round().long(), ys.long())
        epoch_metric += batch_metric
        
    print(f'F-score: {epoch_metric / len(iterator)}, loss: {epoch_loss / len(iterator)}')
        
    return epoch_metric / len(iterator), epoch_loss / len(iterator)# возвращаем среднее значение по всей выборке

# %%
def evaluate(model, iterator, criterion, metric):
    print("\nValidating...")
    epoch_loss = 0
    epoch_metric = 0
    model.eval()
    pred = []
    y = []
    text = [] 
    with torch.no_grad():
        for i, (texts, symbols, ys) in enumerate(iterator):   
            preds = model(texts, symbols).squeeze()  # делаем предсказания на тесте
            loss = criterion(preds, ys)   # считаем значения функции ошибки для статистики  
            epoch_loss += loss.item()
            batch_metric = metric(preds.round().long(), ys.long(), ignore_index=0)
            epoch_metric += batch_metric
            pred.extend(preds.round().cpu().tolist())
            y.extend(ys.cpu().tolist())
            text.extend(texts.cpu().tolist())

    print(f'F-score: {epoch_metric / len(iterator)}, loss: {epoch_loss / len(iterator)}')
        
    return epoch_metric / len(iterator), epoch_loss / len(iterator), text, pred, y # возвращаем среднее значение по всей выборке

# %% [markdown]
# В целом качество этой модели лучше, чем предыдущей, даже с меньшим лернинг рейтом

# %%
model = MixedModel(len(lemma2id), len(symbol2id), 8)
texts, preds, ys = train_model(model, 0.0001, 3)
# Out:
# starting Epoch 0
# Training...
# F-score: 0.5283611416816711, loss: 0.6911715675407732
#
# Validating...
# F-score: 0.5676530003547668, loss: 0.6839378509628639
#
# starting Epoch 1
# Training...
# F-score: 0.6234907507896423, loss: 0.6717464334528211
#
# Validating...
# F-score: 0.7041453123092651, loss: 0.6528091651670048
#
# starting Epoch 2
# Training...
# F-score: 0.7885995507240295, loss: 0.6144483237199381
#
# Validating...
# F-score: 0.8563372492790222, loss: 0.5650047077221817

# %%
model = MixedModel(len(lemma2id), len(symbol2id), 8)
texts, preds, ys = train_model(model, 0.001, 3)
# Out:
# starting Epoch 0
# Training...
# F-score: 0.863972544670105, loss: 0.37670726998591086
#
# Validating...
# F-score: 0.9870110750198364, loss: 0.07366102942255105
#
# starting Epoch 1
# Training...
# F-score: 0.9970766305923462, loss: 0.025617957445727268
#
# Validating...
# F-score: 0.9994733333587646, loss: 0.008515787420773439
#
# starting Epoch 2
# Training...
# F-score: 0.9994387626647949, loss: 0.005774067828274319
#
# Validating...
# F-score: 0.9996927976608276, loss: 0.0035480288186979093

# %%
train_dataset = TwoWayTweetsDataset(train_sentences, word2id, symbol2id, DEVICE)
train_sampler = RandomSampler(train_dataset)
train_iterator = DataLoader(train_dataset, collate_fn = train_dataset.collate_fn, sampler=train_sampler, batch_size=512)
val_dataset = TwoWayTweetsDataset(val_sentences, word2id, symbol2id, DEVICE)
val_sampler = SequentialSampler(val_dataset)
val_iterator = DataLoader(val_dataset, collate_fn = val_dataset.collate_fn, sampler=val_sampler, batch_size=512)

# %%
model = MixedModel(len(word2id), len(symbol2id), 8)
texts, preds, ys = train_model(model, 0.001, 3)
# Out:
# starting Epoch 0
# Training...
# F-score: 0.8290784955024719, loss: 0.3862816308270878
#
# Validating...
# F-score: 0.9808809161186218, loss: 0.07034879927052541
#
# starting Epoch 1
# Training...
# F-score: 0.9921929836273193, loss: 0.0362561690739133
#
# Validating...
# F-score: 0.9959312081336975, loss: 0.021461004590134274
#
# starting Epoch 2
# Training...
# F-score: 0.9970675110816956, loss: 0.012201100909872585
#
# Validating...
# F-score: 0.9988888502120972, loss: 0.006094235178669182

# %% [markdown]
# При увеличении лернинг рейта увеличивается качество! При этом качество хорошее и на леммах, и на токенах

# %%
compare_preds_ys(texts, preds, ys, id2word)
# Out:
# text: rt вот никак определится не может бедная t
#  label: 0.0, prediction: 1.0
# text: rt поскорее бы уже t
#  label: 1.0, prediction: 0.0
# text: пришла ну и погуляли пошли на каток он закрыт пошли гулять с
#  label: 0.0, prediction: 1.0
# text: под окнами на гитаре играют песни такие с ними спеть охота ностальгия прям как 1 5 года назад
#  label: 0.0, prediction: 1.0
# text: panfilenko_olga назовем это d
#  label: 0.0, prediction: 1.0
# text: ааа я сейчас видела такого мужчину если он вернется в магазин то он моя судьба d
#  label: 0.0, prediction: 1.0
# text: про меня сегодня все забыли кроме
#  label: 0.0, prediction: 1.0
# text: rt ierowaybja molko_od в ленте почти все о аниме заговорили я ж не про всех имел ввиду а тех кто начал писать
#  label: 0.0, prediction: 1.0
# text: x_kid_xx я наверное не смогу после 4 или смогу а раньше не можешь а с нами кто нибудь ещё пойдёт
#  label: 0.0, prediction: 1.0
# text: rt sava_fox_x о спасибо я бы тоже хотел провести с тобой нг з
#  label: 1.0, prediction: 0.0
# text: rt утра лента завтра в школу
#  label: 0.0, prediction: 1.0
# text: rt научился репозиторий на github спасибо
#  label: 1.0, prediction: 0.0
# text: картофельное рагу из кролика на красном вине с домашним и салатом из зеленой редьки t
#  label: 1.0, prediction: 0.0
# text: любимый мой родной приходи скорее мне очень очень плохо без тебя я тебя безумно люблю и очень жду
#  label: 0.0, prediction: 1.0
# text: rt какое фото t
#  label: 1.0, prediction: 0.0
# text: xenia_sobchak происки кремля и
#  label: 0.0, prediction: 1.0
# text: medvedofrussia закон выборов в t o_o d d
#  label: 0.0, prediction: 1.0
# text: парень привет что делаешь девушка привет я пипец как хочу срать п o_o д dd
#  label: 0.0, prediction: 1.0
# text: мне нужно твоё слово что ты не своим людям ничего со мной сделать
#  label: 1.0, prediction: 0.0
# text: очень очень классный день очень жаль однако что с так мало повидалась
#  label: 0.0, prediction: 1.0
# text: rt horanso_on вангую имя фандом город др жду
#  label: 0.0, prediction: 1.0
# text: китай прислал наконец то d было написано подарок но его не оказалось t
#  label: 0.0, prediction: 1.0
# text: mamo_oru вангую для тебя с карие черные аниме 15 16 обожаю аниме потекли слюни
#  label: 0.0, prediction: 1.0
# text: я только за тем более что физру я уже сдала
#  label: 1.0, prediction: 0.0
# text: сегодня на прекрасное вальс приятных выходных
#  label: 1.0, prediction: 0.0
# text: отличный вечер с любимой но мы совершенно не выспались пишу и засыпаю а первым уроком к р по английскому не хочу в школу хочу спать
#  label: 0.0, prediction: 1.0
# text: movie сказал что гавно для овец я склонен ему верить
#  label: 1.0, prediction: 0.0
# text: rt mychemicalways schipperlarry69 спасибо большое t
#  label: 1.0, prediction: 0.0
# text: этой зимой меня согреет только кошка t
#  label: 1.0, prediction: 0.0
# text: прошлое его не гарантирует а будущее не может его обещать instantfollowback
#  label: 1.0, prediction: 0.0
# text: разбитое сердце слезы на глазах пустота на душе и только на губах слова вернись я люблю тебя t
#  label: 0.0, prediction: 1.0
# text: нет ничего более приятного для чем оригинальное качественное масло t
#  label: 1.0, prediction: 0.0
# text: да жаль но мы все равно еще пойдем
#  label: 0.0, prediction: 1.0
# text: мне нравится твой юп шапка и оформление
#  label: 1.0, prediction: 0.0
# text: угадай кто вылазит из воды 8 3 пи ды о_о дат 7 класс надо сжечь эти дневники ахахаха но жалко хd
#  label: 0.0, prediction: 1.0
# text: demon_deer его фамилию не так часто упоминают а этот жан одно время на каждом углу был
#  label: 0.0, prediction: 1.0
# text: rt надеюсь что за мной не придёт
#  label: 1.0, prediction: 0.0
# text: is made in china выступят в клубе da da t
#  label: 1.0, prediction: 0.0
# text: вот так я выгляжу когда болею и никакой заботы рядом все сама зато с любимой встречусь сегодня радует t
#  label: 0.0, prediction: 1.0
# text: rt сегодня потрогала первый раз снег на улицу болела
#  label: 0.0, prediction: 1.0
# text: клубняк это надо послушать d mp3 t
#  label: 1.0, prediction: 0.0
# text: опа вот только бы еще улыбочку на лицо и вообще нет слов
#  label: 1.0, prediction: 0.0
# text: ты че афигела а как же физика d
#  label: 0.0, prediction: 1.0
# text: rt icarelajno животное покинуло автобус не не я мне еще ехать и ехать а вот с вышли
#  label: 1.0, prediction: 0.0
# text: tako_o46 это в микрофон говорила d
#  label: 0.0, prediction: 1.0
# text: чойта вы смеетесь над названиями
#  label: 0.0, prediction: 1.0
# text: любимая уезжает не успели увидеться до нг солнце завалюсь к те в 2014 г куплю те кучу подарков и как те обещала сделаю снеговиков
#  label: 0.0, prediction: 1.0
# text: с рождеством твиттерский хороших друзей и приятных моментов тебе
#  label: 0.0, prediction: 1.0
# text: я не думаю что в этом есть необходимость follow
#  label: 1.0, prediction: 0.0
# text: две новости 1 плохая завтра в школу 2 хорошая я теперь на
#  label: 0.0, prediction: 1.0
# text: да на улице ваще говно летает я когда на рынок ходила меня ваще чуть не умело ветром как dd
#  label: 0.0, prediction: 1.0

# %% [markdown]
# В случае со второй моделью проблемы тоже встречаются в основном в случаях, когда используются окрашенные слова (например, "хорошая"), но при этом общий смысл негативный. Модель чаще принимает негативные за позитивные предложения

# %% [markdown]
# ## Анализ
#
# 1. Модель с символьными и пословными эмбеддингами работает лучше: вероятно, это можно объяснить, что не вся пунктуация убирается, и некоторые символьные значения помогают однозначно определять тональность
#
# 2. Для обеих моделей оптимален learning rate 0.001, при таком лернинг рейте они достигают минимума (или приближаются к нему), при меньшем lr шаг слишком маленький.
#
# 3. Предобученные эмбеддинги работают лучше, чем обучаемые внутри модели. Вероятно, модель не успевает за три эпохи хорошо обучить эмбеддинги, поэтому ей помогают предобученные эмбеддинги.
#
# 4. Увеличение размера эмбеддингов увеличивает качество, так как хранится больше информации.
#
# 5. С леммами модель работает лучше, так как объединяет токены в одну лемму и получает о ней больше информации
